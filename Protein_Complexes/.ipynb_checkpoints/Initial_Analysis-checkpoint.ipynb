# %% [markdown]
# # Protein Complexes in Ovarian Cancer

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Import patient data as well as a list of protein complexes from CORUM (http://mips.helmholtz-muenchen.de/corum/#download 'Complete Complexes')

# %%
data = pd.read_csv('proteinGroups_cleaned.txt', sep='\t')
complexData = pd.read_csv('allComplexes.txt', sep='\t')
data
# Out:
#       Gene_Name       01OV007   01OV007_NM   01OV008_NM    01OV010_NM  \
# 0         RBM47  6.632300e+07          0.0          0.0  0.000000e+00
# 1          A1CF  6.632300e+07          0.0          0.0  0.000000e+00
# 2          UBA6  1.191900e+09          0.0  404400000.0  0.000000e+00
# 3         ESYT2  8.069400e+08          0.0          0.0  0.000000e+00
# 4         MED19  0.000000e+00          0.0          0.0  0.000000e+00
# 5         IGLC7  1.087100e+08          0.0          0.0  0.000000e+00
# 6         SHTN1  5.944200e+08          0.0          0.0  0.000000e+00
# 7         DAPL1  0.000000e+00          0.0          0.0  0.000000e+00
# 8         MEX3A  0.000000e+00          0.0          0.0  0.000000e+00
# 9         ILVBL  4.620300e+08  134350000.0          0.0  1.628500e+08
# 10        SSC5D  0.000000e+00  122480000.0   90859000.0  0.000000e+00
# 11     SH3PXD2B  2.019100e+08          0.0          0.0  0.000000e+00
# 12      MACROD2  0.000000e+00          0.0          0.0  0.000000e+00
# 13         DYTN  0.000000e+00          0.0          0.0  0.000000e+00
# 14         NBAS  3.370800e+07          0.0          0.0  0.000000e+00
# 15       TARSL2  0.000000e+00          0.0          0.0  0.000000e+00
# 16         VWA8  0.000000e+00          0.0          0.0  0.000000e+00
# 17        SBNO1  0.000000e+00          0.0          0.0  0.000000e+00
# 18        WDR91  9.334500e+07          0.0          0.0  0.000000e+00
# 19        KLRG2  0.000000e+00          0.0          0.0  0.000000e+00
# 20        XIRP2  0.000000e+00          0.0          0.0  7.081700e+09
# 21       VPS37C  3.224900e+07          0.0          0.0  0.000000e+00
# 22      TMEM189  0.000000e+00          0.0          0.0  0.000000e+00
# 23        CNOT1  1.321800e+09          0.0          0.0  0.000000e+00
# 24     MAP1LC3B  4.291400e+07          0.0          0.0  3.559900e+08
# 25    MAP1LC3B2  4.291400e+07          0.0          0.0  3.559900e+08
# 26        PALM3  0.000000e+00          0.0          0.0  0.000000e+00
# 27          PGP  1.056700e+08          0.0          0.0  6.231300e+08
# 28      C5orf51  0.000000e+00          0.0          0.0  0.000000e+00
# 29      POM121B  0.000000e+00          0.0          0.0  0.000000e+00
# ...         ...           ...          ...          ...           ...
# 7004   CHCHD2P9  1.971700e+08          0.0          0.0  0.000000e+00
# 7005       EPN1  3.922600e+08          0.0          0.0  0.000000e+00
# 7006      PXMP4  0.000000e+00          0.0          0.0  0.000000e+00
# 7007     TEX264  0.000000e+00          0.0          0.0  0.000000e+00
# 7008      CEPT1  0.000000e+00          0.0          0.0  0.000000e+00
# 7009     DNMT3A  0.000000e+00          0.0          0.0  0.000000e+00
# 7010       OAS3  9.277000e+08          0.0          0.0  0.000000e+00
# 7011      IKBKG  5.996600e+07          0.0          0.0  0.000000e+00
# 7012    IGF2BP2  1.701200e+08          0.0          0.0  0.000000e+00
# 7013    SLC30A1  0.000000e+00          0.0          0.0  0.000000e+00
# 7014     SLC4A7  0.000000e+00          0.0          0.0  0.000000e+00
# 7015     NDUFB9  1.583800e+08          0.0          0.0  9.234100e+08
# 7016       SQOR  1.156100e+09          0.0          0.0  0.000000e+00
# 7017      CAPN6  0.000000e+00          0.0          0.0  0.000000e+00
# 7018      AP1M2  0.000000e+00          0.0          0.0  0.000000e+00
# 7019      NUMBL  0.000000e+00          0.0          0.0  0.000000e+00
# 7020      FCGBP  5.837800e+07          0.0          0.0  0.000000e+00
# 7021       SCIN  0.000000e+00          0.0          0.0  0.000000e+00
# 7022      DDX49  0.000000e+00          0.0          0.0  0.000000e+00
# 7023      CAPN7  0.000000e+00          0.0          0.0  0.000000e+00
# 7024      WASF2  2.085700e+08          0.0          0.0  0.000000e+00
# 7025       MAU2  0.000000e+00          0.0          0.0  0.000000e+00
# 7026    FAM169A  0.000000e+00          0.0          0.0  0.000000e+00
# 7027      ENPP4  0.000000e+00          0.0          0.0  0.000000e+00
# 7028      ENPP7  0.000000e+00          0.0          0.0  0.000000e+00
# 7029       ZHX2  0.000000e+00          0.0          0.0  0.000000e+00
# 7030       ZHX3  0.000000e+00          0.0          0.0  0.000000e+00
# 7031      MORC2  0.000000e+00          0.0          0.0  0.000000e+00
# 7032   IVNS1ABP  0.000000e+00          0.0          0.0  0.000000e+00
# 7033    SEC23IP  3.207100e+08          0.0  268760000.0  0.000000e+00
#
#         01OV013_NM       01OV017    01OV017_NM       01OV018    01OV019_NM  \
# 0     0.000000e+00  2.547900e+08  0.000000e+00  5.532400e+07  0.000000e+00
# 1     0.000000e+00  2.547900e+08  0.000000e+00  5.532400e+07  0.000000e+00
# 2     0.000000e+00  1.436700e+09  1.148600e+09  2.047900e+09  1.343800e+09
# 3     2.732400e+08  4.981100e+08  2.522700e+08  3.686300e+08  6.054700e+08
# 4     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 5     0.000000e+00  0.000000e+00  1.187900e+08  0.000000e+00  0.000000e+00
# 6     0.000000e+00  2.390600e+08  0.000000e+00  1.552000e+08  9.006500e+07
# 7     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 8     0.000000e+00  0.000000e+00  0.000000e+00  2.450800e+07  0.000000e+00
# 9     0.000000e+00  6.270200e+08  2.709000e+08  6.957900e+08  3.987300e+08
# 10    1.898600e+08  0.000000e+00  6.343300e+07  0.000000e+00  1.106100e+08
# 11    0.000000e+00  2.371800e+08  0.000000e+00  2.430000e+08  1.212100e+08
# 12    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 13    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 14    3.485000e+07  4.195200e+07  0.000000e+00  5.482800e+07  6.240100e+07
# 15    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 16    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 17    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 18    0.000000e+00  0.000000e+00  0.000000e+00  8.197100e+07  4.786000e+07
# 19    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 20    7.059100e+07  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 21    0.000000e+00  2.988000e+07  0.000000e+00  0.000000e+00  0.000000e+00
# 22    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 23    2.135200e+10  1.510400e+09  1.775800e+09  2.065600e+09  2.013700e+09
# 24    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  4.717800e+07
# 25    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  4.717800e+07
# 26    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 27    0.000000e+00  4.397800e+08  0.000000e+00  1.576500e+08  0.000000e+00
# 28    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 29    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...            ...           ...           ...           ...           ...
# 7004  0.000000e+00  1.132300e+08  0.000000e+00  1.445400e+08  1.035000e+08
# 7005  0.000000e+00  2.643700e+08  0.000000e+00  2.685100e+08  2.209400e+08
# 7006  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7007  0.000000e+00  1.070700e+08  0.000000e+00  0.000000e+00  0.000000e+00
# 7008  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7009  0.000000e+00  1.144800e+08  0.000000e+00  1.576600e+08  0.000000e+00
# 7010  0.000000e+00  7.598900e+08  3.441400e+08  1.373800e+09  0.000000e+00
# 7011  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7012  0.000000e+00  2.461600e+08  0.000000e+00  7.324600e+08  1.441500e+08
# 7013  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7014  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7015  2.150100e+08  4.086500e+08  1.656700e+08  2.999600e+08  1.983900e+08
# 7016  1.170300e+09  6.723700e+08  6.874900e+08  1.059400e+09  1.050400e+09
# 7017  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7018  0.000000e+00  7.522500e+07  0.000000e+00  0.000000e+00  0.000000e+00
# 7019  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7020  0.000000e+00  3.212800e+07  0.000000e+00  1.993200e+07  3.562800e+07
# 7021  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7022  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7023  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7024  0.000000e+00  2.438200e+08  2.152600e+08  2.083000e+08  1.451200e+08
# 7025  0.000000e+00  0.000000e+00  0.000000e+00  8.450900e+07  0.000000e+00
# 7026  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7027  9.904800e+07  8.565700e+07  0.000000e+00  0.000000e+00  0.000000e+00
# 7028  9.904800e+07  8.565700e+07  0.000000e+00  0.000000e+00  0.000000e+00
# 7029  0.000000e+00  0.000000e+00  0.000000e+00  3.493500e+07  0.000000e+00
# 7030  0.000000e+00  0.000000e+00  0.000000e+00  3.493500e+07  0.000000e+00
# 7031  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7032  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 7033  0.000000e+00  2.688600e+08  1.287400e+08  2.829400e+08  2.002300e+08
#
#           ...         17OV001_NM       17OV002   17OV002_NM   17OV003_NM  \
# 0         ...       6.270100e+07  2.525300e+08          0.0          0.0
# 1         ...       6.270100e+07  2.525300e+08          0.0          0.0
# 2         ...       9.756600e+08  2.103900e+09          0.0  225790000.0
# 3         ...       4.602200e+08  4.069700e+08          0.0  623870000.0
# 4         ...       0.000000e+00  0.000000e+00          0.0          0.0
# 5         ...       0.000000e+00  0.000000e+00          0.0  188180000.0
# 6         ...       3.132300e+08  2.271200e+08          0.0          0.0
# 7         ...       0.000000e+00  0.000000e+00          0.0          0.0
# 8         ...       0.000000e+00  0.000000e+00          0.0          0.0
# 9         ...       6.178200e+08  4.313800e+08          0.0   95345000.0
# 10        ...       4.943600e+07  0.000000e+00  109450000.0          0.0
# 11        ...       1.359000e+08  2.820900e+08          0.0          0.0
# 12        ...       0.000000e+00  0.000000e+00          0.0          0.0
# 13        ...       0.000000e+00  0.000000e+00          0.0          0.0
# 14        ...       7.913000e+07  8.099500e+07          0.0          0.0
# 15        ...       3.780300e+07  0.000000e+00          0.0          0.0
# 16        ...       0.000000e+00  0.000000e+00          0.0          0.0
# 17        ...       0.000000e+00  0.000000e+00          0.0          0.0
# 18        ...       1.398100e+08  1.135000e+08          0.0          0.0
# 19        ...       0.000000e+00  0.000000e+00          0.0          0.0
# 20        ...       0.000000e+00  0.000000e+00          0.0          0.0
# 21        ...       0.000000e+00  5.646200e+07          0.0          0.0
# 22        ...       0.000000e+00  0.000000e+00          0.0          0.0
# 23        ...       3.958200e+09  1.806500e+09          0.0          0.0
# 24        ...       0.000000e+00  0.000000e+00          0.0          0.0
# 25        ...       0.000000e+00  0.000000e+00          0.0          0.0
# 26        ...       2.189700e+09  0.000000e+00          0.0          0.0
# 27        ...       1.568300e+08  2.033200e+08          0.0          0.0
# 28        ...       0.000000e+00  0.000000e+00          0.0          0.0
# 29        ...       0.000000e+00  2.495000e+07          0.0          0.0
# ...       ...                ...           ...          ...          ...
# 7004      ...       2.130800e+08  1.907800e+08          0.0          0.0
# 7005      ...       2.433000e+08  1.888000e+08          0.0          0.0
# 7006      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7007      ...       0.000000e+00  9.903500e+07          0.0          0.0
# 7008      ...       0.000000e+00  2.959400e+07          0.0          0.0
# 7009      ...       3.108500e+07  4.079300e+07          0.0          0.0
# 7010      ...       6.476600e+08  9.729000e+07          0.0          0.0
# 7011      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7012      ...       9.888600e+07  9.166900e+07          0.0          0.0
# 7013      ...       0.000000e+00  2.396700e+08          0.0          0.0
# 7014      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7015      ...       2.501300e+08  8.219400e+07          0.0          0.0
# 7016      ...       1.211800e+09  1.150400e+09  359900000.0          0.0
# 7017      ...       0.000000e+00  5.775200e+08          0.0          0.0
# 7018      ...       3.538200e+07  6.558600e+08          0.0          0.0
# 7019      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7020      ...       4.089900e+07  1.086000e+08          0.0          0.0
# 7021      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7022      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7023      ...       0.000000e+00  2.828900e+07          0.0          0.0
# 7024      ...       1.854900e+08  2.346400e+08          0.0          0.0
# 7025      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7026      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7027      ...       6.923400e+07  1.493100e+08          0.0          0.0
# 7028      ...       6.923400e+07  1.493100e+08          0.0          0.0
# 7029      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7030      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7031      ...       0.000000e+00  0.000000e+00          0.0          0.0
# 7032      ...       0.000000e+00  2.275600e+08          0.0          0.0
# 7033      ...       2.336400e+08  3.925800e+08          0.0          0.0
#
#        17OV004_NM   17OV005_NM       17OV014       17OV015       17OV018  \
# 0             0.0          0.0  0.000000e+00  0.000000e+00  1.579100e+08
# 1             0.0          0.0  0.000000e+00  0.000000e+00  1.579100e+08
# 2             0.0          0.0  1.092300e+09  1.640500e+09  1.831100e+09
# 3             0.0          0.0  6.994500e+08  4.626500e+08  5.260800e+08
# 4             0.0          0.0  0.000000e+00  0.000000e+00  1.914400e+07
# 5             0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 6             0.0          0.0  2.068300e+08  8.116700e+07  3.273900e+08
# 7             0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 8             0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 9     263050000.0   96172000.0  2.951100e+09  2.927800e+08  6.055900e+08
# 10    211640000.0   80850000.0  0.000000e+00  5.290500e+07  0.000000e+00
# 11            0.0          0.0  2.719400e+08  2.623100e+08  3.458800e+08
# 12            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 13            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 14            0.0          0.0  7.469000e+07  8.158100e+07  7.306400e+07
# 15            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 16            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 17            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 18            0.0          0.0  3.351500e+08  6.749100e+07  0.000000e+00
# 19            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 20            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 21            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 22            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 23            0.0          0.0  4.331500e+09  2.959100e+09  3.281800e+09
# 24            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 25            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 26            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 27            0.0          0.0  1.904000e+08  0.000000e+00  2.183200e+08
# 28            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 29            0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# ...           ...          ...           ...           ...           ...
# 7004          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7005          0.0          0.0  1.799000e+08  2.560200e+08  3.440900e+08
# 7006          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7007          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7008          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7009          0.0          0.0  2.737700e+07  1.358100e+08  4.618800e+07
# 7010          0.0          0.0  4.854100e+08  2.800300e+08  8.927200e+08
# 7011          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7012          0.0          0.0  4.971300e+08  4.431200e+08  9.155400e+08
# 7013          0.0          0.0  6.431600e+07  0.000000e+00  0.000000e+00
# 7014          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7015  210360000.0          0.0  1.920500e+08  3.466300e+08  1.632800e+08
# 7016  525140000.0  696440000.0  6.480000e+08  1.035300e+09  9.996100e+08
# 7017          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7018          0.0          0.0  6.416500e+07  0.000000e+00  0.000000e+00
# 7019          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7020          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7021          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7022          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7023          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7024          0.0          0.0  1.897600e+08  1.701400e+08  3.268700e+08
# 7025          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7026          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7027          0.0          0.0  1.067100e+08  7.335800e+07  0.000000e+00
# 7028          0.0          0.0  1.067100e+08  7.335800e+07  0.000000e+00
# 7029          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7030          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7031          0.0          0.0  0.000000e+00  0.000000e+00  0.000000e+00
# 7032          0.0          0.0  1.215300e+08  0.000000e+00  0.000000e+00
# 7033  128380000.0          0.0  3.545200e+08  3.661500e+08  5.635500e+08
#
#            17OV026
# 0     5.738500e+07
# 1     5.738500e+07
# 2     1.045900e+09
# 3     4.205100e+08
# 4     0.000000e+00
# 5     0.000000e+00
# 6     4.013900e+08
# 7     0.000000e+00
# 8     0.000000e+00
# 9     4.140900e+08
# 10    2.163900e+07
# 11    2.145800e+08
# 12    0.000000e+00
# 13    0.000000e+00
# 14    5.562300e+07
# 15    0.000000e+00
# 16    0.000000e+00
# 17    0.000000e+00
# 18    5.896600e+07
# 19    0.000000e+00
# 20    0.000000e+00
# 21    3.243000e+07
# 22    0.000000e+00
# 23    2.112000e+09
# 24    0.000000e+00
# 25    0.000000e+00
# 26    0.000000e+00
# 27    0.000000e+00
# 28    0.000000e+00
# 29    0.000000e+00
# ...            ...
# 7004  0.000000e+00
# 7005  3.415100e+08
# 7006  0.000000e+00
# 7007  0.000000e+00
# 7008  0.000000e+00
# 7009  3.249700e+07
# 7010  1.487500e+09
# 7011  4.117500e+07
# 7012  2.251000e+08
# 7013  0.000000e+00
# 7014  1.436300e+07
# 7015  1.413400e+08
# 7016  1.156600e+09
# 7017  0.000000e+00
# 7018  0.000000e+00
# 7019  0.000000e+00
# 7020  3.445700e+07
# 7021  0.000000e+00
# 7022  6.359900e+08
# 7023  2.595100e+07
# 7024  2.772200e+08
# 7025  0.000000e+00
# 7026  0.000000e+00
# 7027  1.075800e+08
# 7028  1.075800e+08
# 7029  0.000000e+00
# 7030  0.000000e+00
# 7031  0.000000e+00
# 7032  0.000000e+00
# 7033  2.753900e+08
#
# [7034 rows x 60 columns]

# %% [markdown]
# ### Create a workable dictionary of protein complex information

# %%
# Select for human complexes
complexData = complexData.loc[complexData['Organism'] == 'Human']

# Split the proteins in each complex into invdividual columns of a new df
subunitNames = complexData['subunits(Gene name)'].str.split(';', expand = True)
subunitNames.index = complexData.ComplexName
subunitNames

# Create a dictionary (key = complex name, value = list of proteins in complex) and remove None values
subunitNames = subunitNames.transpose().to_dict('list')
for key, val in subunitNames.items():
    subunitNames[key] = [value for value in val if value != None]
subunitNames
# Out:
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   # Remove the CWD from sys.path while we load stuff.
# {'BCL6-HDAC4 complex': ['BCL6', 'HDAC4'],
#  'BCL6-HDAC5 complex': ['BCL6', 'HDAC5'],
#  'BCL6-HDAC7 complex': ['BCL6', 'HDAC7'],
#  'Multisubunit ACTR coactivator complex': ['EP300',
#   'CREBBP',
#   'KAT2B',
#   'NCOA3'],
#  'Condensin I complex': ['SMC2', 'NCAPH', 'NCAPD2', 'NCAPG', 'SMC4'],
#  'BLOC-3 (biogenesis of lysosome-related organelles complex 3)': ['HPS1',
#   'HPS4'],
#  'BLOC-2 (biogenesis of lysosome-related organelles complex 2)': ['HPS6',
#   'HPS3',
#   'HPS5'],
#  'MUS81-CDS1 complex': ['CDS1', 'MUS81'],
#  'NCOR complex': ['HDAC3', 'TBL1X', 'NCOR1', 'GPS2', 'CORO2A', 'TBL1XR1'],
#  'BLOC-1 (biogenesis of lysosome-related organelles complex 1)': ['SNAPIN',
#   'BLOC1S1',
#   'BLOC1S3',
#   'BLOC1S2',
#   'BLOC1S5',
#   'DTNBP1',
#   'BLOC1S4',
#   'BLOC1S6'],
#  'Arp2/3 protein complex': ['ARPC1B',
#   'ARPC2',
#   'ARPC3',
#   'ARPC5',
#   'ARPC4',
#   'ACTR3',
#   'ACTR2'],
#  'PA28gamma complex': ['PSME3'],
#  'PA28 complex': ['PSME1', 'PSME2'],
#  'PA700 complex': ['PSMD11',
#   'PSMD12',
#   'PSMD9',
#   'PSMD14',
#   'PSMD3',
#   'PSMD10',
#   'PSMC3',
#   'PSMC2',
#   'PSMC4',
#   'PSMD8',
#   'PSMD7',
#   'PSMD4',
#   'PSMC1',
#   'PSMC5',
#   'PSMC6',
#   'PSMD2',
#   'PSMD6',
#   'PSMD5',
#   'PSMD1',
#   'PSMD13'],
#  'Prefoldin complex': ['PFDN6', 'PFDN1', 'VBP1', 'PFDN5', 'PFDN4', 'PFDN2'],
#  'AP1 adaptor complex': ['AP1G1',
#   'AP1G2',
#   'AP1S2',
#   'AP1S1',
#   'AP1B1',
#   'AP1S3',
#   'AP1M1',
#   'AP1M2'],
#  'Mi-2/NuRD-MTA3 complex': ['MTA2', 'MBD3', 'BCL6', 'HDAC1', 'MTA3'],
#  'Gamma-secretase complex (APH1A, PSEN1, PSENEN, NCSTN)': ['PSEN1',
#   'NCSTN',
#   'APH1A',
#   'PSENEN'],
#  'DNMT3B complex': ['SMARCA5',
#   'KIF4A',
#   'SMC2',
#   'HDAC1',
#   'SIN3A',
#   'SMC4',
#   'DNMT3B'],
#  'RAB5-RABAPTIN5\\u2013RABEX5 complex': ['RAB5A', 'RABEP1', 'RABGEF1'],
#  'SIN3 complex': ['SAP18',
#   'SAP30',
#   'RBBP4',
#   'HDAC1',
#   'RBBP7',
#   'HDAC2',
#   'SIN3A'],
#  'HDAC4-ERK1 complex': ['MAPK3', 'HDAC4'],
#  'HDAC4-ERK2 complex': ['MAPK1', 'HDAC4'],
#  'SMRT complex': ['HDAC3', 'TBL1X', 'GPS2', 'TBL1XR1', 'NCOR2'],
#  'AP3 adaptor complex': ['AP3B1',
#   'AP3D1',
#   'AP3M2',
#   'AP3S2',
#   'AP3B2',
#   'AP3S1',
#   'AP3M1'],
#  'Interferon-stimulated gene factor 3 transcription complex ISGF3': ['STAT1',
#   'STAT2',
#   'IRF9'],
#  'Mi2/NuRD complex': ['MTA2',
#   'MBD3',
#   'RBBP4',
#   'HDAC1',
#   'CHD4',
#   'RBBP7',
#   'HDAC2'],
#  'MeCP1 complex': ['MTA2',
#   'MBD3',
#   'RBBP4',
#   'HDAC1',
#   'CHD4',
#   'RBBP7',
#   'GATAD2B',
#   'HDAC2',
#   'MBD2'],
#  'Cohesin-SA1 complex': ['RAD21', 'SMC1A', 'STAG1', 'SMC3'],
#  'Cohesin-SA2 complex': ['RAD21', 'SMC1A', 'STAG2', 'SMC3'],
#  'TRAP complex': ['MED14',
#   'MED24',
#   'MED6',
#   'THRA',
#   'CCNC',
#   'MED21',
#   'MED1',
#   'MED27',
#   'MED12',
#   'MED10',
#   'MED4',
#   'MED17',
#   'MED13',
#   'THRAP3',
#   'MED16',
#   'MED31'],
#  'AP4 adaptor complex': ['AP4M1', 'AP4E1', 'AP4S1', 'AP4B1'],
#  'BCDX2 complex': ['RAD51B', 'RAD51C', 'XRCC2', 'RAD51D'],
#  'MRN complex (MRE11-RAD50-NBN complex)': ['NBN', 'MRE11A', 'RAD50'],
#  'R/M complex (RAD50-MRE11 complex)': ['MRE11A', 'RAD50'],
#  'HOMER3-IP3R-TRPC1 complex': ['TRPC1', 'ITPR3', 'HOMER3'],
#  'TSC1-TSC2 complex': ['TSC2', 'TSC1'],
#  'Ubiquitin E3 ligase (SKP1A, SKP2, CUL1, RBX1)': ['RBX1',
#   'SKP1',
#   'SKP2',
#   'CUL1'],
#  'Ubiquitin E3 ligase (SKP1A, FBXW8, CUL7, RBX1)': ['RBX1',
#   'SKP1',
#   'CUL7',
#   'FBXW8'],
#  'NUMAC complex (nucleosomal methylation activator complex)': ['ARID1A',
#   'SMARCA4',
#   'ACTB',
#   'SMARCB1',
#   'CARM1',
#   'SMARCC2',
#   'SMARCC1',
#   'SMARCE1',
#   'SMARCD1',
#   'SCYL1'],
#  'Nup 107-160 subcomplex': ['NUP98',
#   'SEC13',
#   'NUP107',
#   'NUP160',
#   'NUP43',
#   'NUP37',
#   'NUP133',
#   'SEH1L',
#   'NUP85'],
#  'Exocyst Sec6/8 complex': ['EXOC5',
#   'EXOC3',
#   'EXOC8',
#   'EXOC6',
#   'EXOC4',
#   'EXOC2',
#   'EXOC1',
#   'EXOC7'],
#  'FA complex (Fanconi anemia complex), cytoplasmic': ['FANCG',
#   'FANCA',
#   'FANCC',
#   'FANCF'],
#  'CD28-transactivation complex': ['CD28', 'NCL'],
#  'Anaphase-promoting complex': ['CDC27',
#   'CDC16',
#   'ANAPC1',
#   'CDC23',
#   'ANAPC7',
#   'ANAPC5',
#   'ANAPC4',
#   'ANAPC2',
#   'ANAPC10'],
#  'SNF2H-BAZ1A complex': ['SMARCA5', 'BAZ1A'],
#  'Ku antigen-NARG1 complex': ['XRCC6', 'XRCC5', 'NAA15'],
#  'p300-MDM2-p53 protein complex': ['TP53', 'MDM2', 'EP300'],
#  'hNURF complex': ['SMARCA1', 'RBBP4', 'BPTF', 'RBBP7'],
#  'RNA polymerase II holoenzyme complex': ['POLR2D',
#   'GTF2F2',
#   'ERCC2',
#   'POLR2C',
#   'POLR2E',
#   'ERCC3',
#   'TBP',
#   'POLR2A',
#   'GTF2E1',
#   'GTF2E2',
#   'POLR2B',
#   'GTF2H1',
#   'GTF2F1',
#   'POLR2I',
#   'POLR2H',
#   'POLR2J',
#   'POLR2K',
#   'POLR2F',
#   'POLR2G',
#   'POLR2L',
#   'GTF2B',
#   'GTF2H2',
#   'GTF2H3',
#   'GTF2H4'],
#  'RNA polymerase II core complex': ['POLR2D',
#   'POLR2C',
#   'POLR2E',
#   'POLR2A',
#   'POLR2B',
#   'POLR2I',
#   'POLR2H',
#   'POLR2J',
#   'POLR2K',
#   'POLR2F',
#   'POLR2G',
#   'POLR2L'],
#  'Polycomb repressive complex 2 (PRC 2)': ['EED',
#   'RBBP4',
#   'SUZ12',
#   'EZH2',
#   'RBBP7'],
#  'TFIIH transcription factor complex': ['ERCC2',
#   'ERCC3',
#   'GTF2H1',
#   'CDK7',
#   'CCNH',
#   'MNAT1',
#   'GTF2H2',
#   'GTF2H3',
#   'GTF2H4'],
#  'SNAPc (small nuclear RNA-activating protein) complex': ['SNAPC5',
#   'SNAPC2',
#   'SNAPC1',
#   'SNAPC4',
#   'SNAPC3'],
#  'Polycomb repressive complex 1 (PRC1, hPRC-H)': ['CBX4',
#   'SMARCA5',
#   'HSPA1A',
#   'YY1',
#   'BMI1',
#   'PHC1',
#   'RING1',
#   'CBX2',
#   'PHC2',
#   'PHC3',
#   'SCMH1',
#   'RNF2',
#   'CBX8'],
#  'GPR56-CD81-Galpha(q/11)-Gbeta complex': ['GNA11',
#   'GNAQ',
#   'CD81',
#   'GNB1',
#   'ADGRG1'],
#  'GPI-GnT activity complex': ['PIGA', 'PIGH', 'PIGC', 'PIGQ'],
#  'Lymphotoxin beta receptor complex': ['LTA', 'LTBR', 'LTB'],
#  'Rnase/Mrp complex': ['POP7',
#   'RPP40',
#   'RPP14',
#   'POP4',
#   'RPP38',
#   'RPP30',
#   'POP5',
#   'POP1',
#   'RPP25',
#   'RPP21'],
#  'CCT complex (chaperonin containing TCP1 complex)': ['TCP1',
#   'CCT6A',
#   'CCT5',
#   'CCT3',
#   'CCT8',
#   'CCT4',
#   'CCT2',
#   'CCT7'],
#  'NDC80 kinetochore complex': ['NDC80', 'SPC24', 'NUF2', 'SPC25'],
#  'PIDDsome complex': ['CASP2', 'CRADD', 'PIDD1'],
#  'Telomere-associated protein complex': ['TERF1',
#   'TERF2',
#   'ACD',
#   'TINF2',
#   'POT1',
#   'TERF2IP'],
#  'E-box sequence-binding complex': ['LMO2', 'NHLH2', 'LDB1', 'BEX2'],
#  'CD147-gamma-secretase complex': ['BSG', 'PSEN1', 'NCSTN', 'APH1A', 'PSENEN'],
#  'APP-APBB1-LRP1 complex': ['APBB1', 'APP', 'LRP1'],
#  'Gamma-BAR-AP1 complex': ['AP1G1',
#   'AP1G2',
#   'AP1S2',
#   'AP1S1',
#   'AP1B1',
#   'AP1AR',
#   'AP1S3',
#   'AP1M1',
#   'AP1M2'],
#  'PBAF complex (Polybromo- and BAF containing complex)': ['ACTL6A',
#   'SMARCA4',
#   'SMARCB1',
#   'ARID2',
#   'PBRM1',
#   'SMARCC2',
#   'SMARCC1',
#   'SMARCE1',
#   'SMARCD1'],
#  'TFIIE complex': ['GTF2E1', 'GTF2E2'],
#  'TFIIF complex (transcription factor IIF)': ['GTF2F2', 'GTF2F1'],
#  'TFIID complex': ['TAF4',
#   'TBP',
#   'TAF1',
#   'TAF6',
#   'TAF5',
#   'TAF11',
#   'TAF12',
#   'TAF9',
#   'TAF2'],
#  'Retrotranslocation complex': ['GEMIN4', 'SYVN1', 'DERL1'],
#  'Condensin I-PARP-1-XRCC1 complex': ['SMC2',
#   'PARP1',
#   'XRCC1',
#   'NCAPH',
#   'NCAPD2',
#   'NCAPG',
#   'SMC4'],
#  'Condensin II': ['SMC2', 'NCAPD3', 'NCAPH2', 'NCAPG2', 'SMC4'],
#  'COG complex': ['COG7',
#   'COG2',
#   'COG1',
#   'COG3',
#   'COG8',
#   'COG4',
#   'COG5',
#   'COG6'],
#  'OGT-TRAK1-TRAK2 complex': ['OGT', 'TRAK2', 'TRAK1'],
#  'Respiratory chain complex I (holoenzyme), mitochondrial': ['NDUFS8',
#   'NDUFA4',
#   'NDUFAB1',
#   'NDUFA1',
#   'NDUFS4',
#   'NDUFB5',
#   'NDUFB3',
#   'NDUFC1',
#   'NDUFA2',
#   'NDUFS5',
#   'NDUFS7',
#   'NDUFS2',
#   'NDUFS6',
#   'NDUFB1',
#   'NDUFS3',
#   'NDUFB6',
#   'NDUFA3',
#   'NDUFB4',
#   'NDUFB8',
#   'NDUFB2',
#   'NDUFA7',
#   'NDUFC2',
#   'NDUFA10',
#   'NDUFB10',
#   'MT-ND1',
#   'MT-ND2',
#   'MT-ND3',
#   'MT-ND4L',
#   'MT-ND5',
#   'MT-ND6',
#   'NDUFB7',
#   'NDUFV2',
#   'NDUFS1',
#   'NDUFV1',
#   'NDUFA8',
#   'NDUFV3',
#   'NDUFA6',
#   'NDUFA5',
#   'NDUFA9',
#   'NDUFA11',
#   'NDUFB11',
#   'NDUFA13',
#   'NDUFA12',
#   'NDUFB9'],
#  'PNUTS-PP1 complex': ['PPP1CA', 'PPP1R10'],
#  '26S proteasome': ['PSMA7',
#   'PSMC3',
#   'PSMB1',
#   'PSMA1',
#   'PSMA2',
#   'PSMA3',
#   'PSMA4',
#   'PSMA5',
#   'PSMB4',
#   'PSMB6',
#   'PSMB5',
#   'PSMC2',
#   'PSMC4',
#   'PSMB3',
#   'PSMB2',
#   'PSMD4',
#   'PSMA6',
#   'PSMC1',
#   'PSMC5',
#   'PSMC6',
#   'PSMB7',
#   'PSMD13'],
#  'Wave-2 complex': ['CYFIP1', 'ABI1', 'BRK1', 'NCKAP1', 'WASF2'],
#  'BAF complex': ['ARID1A',
#   'ACTL6A',
#   'SMARCA2',
#   'SMARCB1',
#   'SMARCC2',
#   'SMARCC1',
#   'SMARCE1',
#   'SMARCD1'],
#  'Mitotic checkpoint complex (MCC)': ['BUB3', 'BUB1B', 'CDC20', 'MAD2L1'],
#  '20S proteasome': ['PSMA7',
#   'PSMB1',
#   'PSMA1',
#   'PSMA2',
#   'PSMA3',
#   'PSMA4',
#   'PSMA5',
#   'PSMB4',
#   'PSMB6',
#   'PSMB5',
#   'PSMB3',
#   'PSMB2',
#   'PSMA6',
#   'PSMB7'],
#  'PA28-20S proteasome': ['PSMA7',
#   'PSMB1',
#   'PSMA1',
#   'PSMA2',
#   'PSMA3',
#   'PSMA4',
#   'PSMA5',
#   'PSMB4',
#   'PSMB6',
#   'PSMB5',
#   'PSMB3',
#   'PSMB2',
#   'PSMA6',
#   'PSME1',
#   'PSMB7',
#   'PSME2'],
#  'PA700-20S-PA28 complex': ['PSMD11',
#   'PSMD12',
#   'PSMD9',
#   'PSMD14',
#   'PSMA7',
#   'PSMD3',
#   'PSMD10',
#   'PSMC3',
#   'PSMB1',
#   'PSMA1',
#   'PSMA2',
#   'PSMA3',
#   'PSMA4',
#   'PSMA5',
#   'PSMB4',
#   'PSMB6',
#   'PSMB5',
#   'PSMC2',
#   'PSMC4',
#   'PSMD8',
#   'PSMB3',
#   'PSMB2',
#   'PSMD7',
#   'PSMD4',
#   'PSMA6',
#   'PSMC1',
#   'PSMC5',
#   'PSMC6',
#   'PSME1',
#   'PSMD2',
#   'PSMD6',
#   'PSMD5',
#   'PSMB7',
#   'PSMD1',
#   'PSME2',
#   'PSMD13'],
#  'PA28gamma-20S proteasome': ['PSMA7',
#   'PSMB1',
#   'PSMA1',
#   'PSMA2',
#   'PSMA3',
#   'PSMA4',
#   'PSMA5',
#   'PSMB4',
#   'PSMB6',
#   'PSMB5',
#   'PSMB3',
#   'PSMB2',
#   'PSMA6',
#   'PSME3',
#   'PSMB7'],
#  'HUIC complex': ['BRCA1', 'BARD1'],
#  'BRCA1-RAD50-MRE11-NBS1 complex': ['NBN', 'BRCA1', 'MRE11A', 'RAD50'],
#  'Ubiquitin E3 ligase (VHL, TCEB1, TCEB2, CUL2, RBX1)': ['VHL',
#   'RBX1',
#   'CUL2',
#   'TCEB1',
#   'TCEB2'],
#  'DNA ligase IV-XRCC4 complex': ['LIG4', 'XRCC4'],
#  'Ubiquitin E3 ligase (ASB2, TCEB1, TCEB2, CUL5, RNF7)': ['TCEB1',
#   'TCEB2',
#   'CUL5',
#   'ASB2',
#   'RNF7'],
#  'Ubiquitin E3 ligase (ASB1, TCEB1, TCEB2, CUL5, RNF7)': ['TCEB1',
#   'TCEB2',
#   'CUL5',
#   'RNF7',
#   'ASB1'],
#  'Ubiquitin E3 ligase (ASB6, TCEB1, TCEB2, CUL5, RNF7)': ['TCEB1',
#   'TCEB2',
#   'CUL5',
#   'ASB6',
#   'RNF7'],
#  'Ubiquitin E3 ligase (ASB7, TCEB1, TCEB2, CUL5, RNF7)': ['TCEB1',
#   'TCEB2',
#   'CUL5',
#   'ASB7',
#   'RNF7'],
#  'Ubiquitin E3 ligase (ASB12, TCEB1, TCEB2, CUL5, RNF7)': ['TCEB1',
#   'TCEB2',
#   'ASB12',
#   'CUL5',
#   'RNF7'],
#  'DNA ligase III-XRCC1 complex': ['XRCC1', 'LIG3'],
#  'DNA ligase IV-XRCC1 complex': ['XRCC1', 'LIG4'],
#  'Ubiquitin E3 ligase (WSB1, TCEB1, TCEB2, CUL5, RBX1)': ['RBX1',
#   'TCEB1',
#   'TCEB2',
#   'CUL5',
#   'WSB1'],
#  'CRSP complex': ['MED7',
#   'MED14',
#   'MED24',
#   'MED6',
#   'MED26',
#   'MED21',
#   'MED1',
#   'MED25',
#   'MED15',
#   'MED17',
#   'MED23'],
#  'CAND1-CUL1-RBX1 complex': ['RBX1', 'CUL1', 'CAND1'],
#  'ARF-Mule complex': ['NPM1', 'HUWE1', 'CDKN2A'],
#  'CAND1-CUL2-RBX1 complex': ['RBX1', 'CUL2', 'CAND1'],
#  'CAND1-CUL3-RBX1 complex': ['RBX1', 'CUL3', 'CAND1'],
#  'CAND1-CUL4A-RBX1 complex': ['RBX1', 'CUL4A', 'CAND1'],
#  'CAND1-CUL4B-RBX1 complex': ['RBX1', 'CUL4B', 'CAND1'],
#  'Ubiquitin E3 ligase (SKP1A, SKP2, CUL1)': ['SKP1', 'SKP2', 'CUL1'],
#  'Ubiquitin E3 ligase (SKP1A, BTRC, CUL1)': ['SKP1', 'CUL1', 'BTRC'],
#  'SMCC complex': ['MED14',
#   'MED24',
#   'MED6',
#   'CCNC',
#   'CDK8',
#   'MED21',
#   'MED1',
#   'MED27',
#   'MED12',
#   'MED4',
#   'MED17',
#   'MED13',
#   'THRAP3',
#   'MED16'],
#  'NAT complex': ['MED14', 'MED6', 'CCNC', 'CDK8', 'MED21', 'MED10', 'MED23'],
#  'Mediator complex': ['MED19',
#   'MED7',
#   'MED14',
#   'OPA1',
#   'MED24',
#   'MED6',
#   'MED26',
#   'MED21',
#   'MED22',
#   'MED1',
#   'MED27',
#   'MED13L',
#   'MED25',
#   'MED8',
#   'MED30',
#   'MED15',
#   'MED10',
#   'MED18',
#   'MED20',
#   'MED4',
#   'MED17',
#   'MED29',
#   'MED11',
#   'MED13',
#   'MED23',
#   'MED16',
#   'MED31'],
#  'ARC complex': ['MED7',
#   'MED14',
#   'MED24',
#   'MED6',
#   'MED26',
#   'CCNC',
#   'CDK8',
#   'MED21',
#   'MED1',
#   'MED25',
#   'MED12',
#   'MED15',
#   'MED17',
#   'MED13',
#   'MED23'],
#  'HuCHRAC complex': ['SMARCA5', 'POLE3', 'CHRAC1', 'BAZ1A'],
#  'WICH complex': ['SMARCA5', 'BAZ1B'],
#  'SWI-SNF chromatin remodeling-related-BRCA1 complex': ['ARID1A',
#   'ACTL6A',
#   'BRCA1',
#   'SMARCA2',
#   'SMARCA4',
#   'SMARCB1',
#   'SMARCC2',
#   'SMARCC1',
#   'SMARCD2',
#   'SMARCE1'],
#  'BRCA1-CTIP-ZBRK1 repressor complex': ['BRCA1', 'RBBP8', 'ZNF350'],
#  'BRCA1-BACH1 complex': ['BRCA1', 'BRIP1'],
#  'RalBP1-CDC2-CCNB1 complex': ['CDK1', 'CCNB1', 'RALBP1'],
#  'BRAFT complex': ['FANCG',
#   'FANCA',
#   'RPA2',
#   'RPA1',
#   'RPA3',
#   'BLM',
#   'FANCC',
#   'TOP3A',
#   'FANCE',
#   'FANCF',
#   'FANCL'],
#  'FA core complex (Fanconi anemia core complex)': ['FANCG',
#   'FANCA',
#   'FANCC',
#   'FANCM',
#   'FANCB',
#   'FANCE',
#   'FANCF'],
#  'BLM complex III': ['MLH1', 'BLM', 'TOP3A', 'RMI1'],
#  'RalBP1-CCNB1-AP2A-NUMB-EPN1 complex': ['AP2A1',
#   'CCNB1',
#   'NUMB',
#   'RALBP1',
#   'EPN1'],
#  'RAD51C-XRCC3 complex': ['RAD51C', 'XRCC3'],
#  'TBPIP/HOP2-MND1 complex': ['MND1', 'PSMC3IP'],
#  'RAD51B-RAD51C complex': ['RAD51B', 'RAD51C'],
#  'RAD51B-RAD51C-RAD51D-XRCC2-XRCC3 complex': ['RAD51B',
#   'RAD51C',
#   'XRCC3',
#   'XRCC2',
#   'RAD51D'],
#  'RAD51L3-XRCC2 complex': ['XRCC2', 'RAD51D'],
#  'ATR-ATRIP complex': ['ATR', 'ATRIP'],
#  'RAD17-RFC complex': ['RAD17', 'RFC4', 'RFC2', 'RFC5', 'RFC3'],
#  '9-1-1 complex': ['RAD1', 'HUS1', 'RAD9A'],
#  '9-1-1-RAD17-RFC complex': ['RAD1',
#   'HUS1',
#   'RAD17',
#   'RFC4',
#   'RFC2',
#   'RFC5',
#   'RFC3',
#   'RAD9A'],
#  'RFC complex': ['RFC4', 'RFC2', 'RFC1', 'RFC5', 'RFC3'],
#  'RFC core complex': ['RFC4', 'RFC2', 'RFC5'],
#  'HMGB1-HMGB2-HSC70-ERP60-GAPDH complex': ['GAPDH',
#   'HMGB1',
#   'HSPA8',
#   'HMGB2',
#   'PDIA3'],
#  'NELF complex (Negative elongation factor complex)': ['NELFE',
#   'NELFCD',
#   'NELFB',
#   'NELFA'],
#  'SNF2h-cohesin-NuRD complex': ['RAD21',
#   'SMARCA5',
#   'MTA2',
#   'MBD3',
#   'RBBP4',
#   'CHD3',
#   'MTA1',
#   'HDAC1',
#   'SMC1A',
#   'RBBP7',
#   'STAG2',
#   'STAG1',
#   'HDAC2',
#   'BAZ1A',
#   'MBD2',
#   'SMC3'],
#  'Sin3 complex': ['SAP18',
#   'SAP30',
#   'RBBP4',
#   'HDAC1',
#   'RBBP7',
#   'HDAC2',
#   'SIN3A'],
#  'PCNA-MLH1-PMS1 complex': ['PCNA', 'MLH1', 'PMS1'],
#  'PCNA-MSH2-MSH6 complex': ['PCNA', 'MSH2', 'MSH6'],
#  'ARC-L complex': ['MED7',
#   'MED14',
#   'MED24',
#   'MED6',
#   'CCNC',
#   'CDK8',
#   'MED21',
#   'MED1',
#   'MED25',
#   'MED12',
#   'MED15',
#   'MED17',
#   'MED13',
#   'MED23'],
#  'MSH2-MLH1-PMS2-PCNA DNA-repair initiation complex': ['PCNA',
#   'MLH1',
#   'MSH2',
#   'PMS2'],
#  'MSH2-MLH1-PMS2 DNA-repair initiation complex': ['MLH1', 'MSH2', 'PMS2'],
#  'MutL-alpha complex': ['MLH1', 'PMS2'],
#  'PCNA-DNA polymerase delta complex': ['PCNA',
#   'POLD1',
#   'POLD2',
#   'POLD3',
#   'POLD4'],
#  'VEGF transcriptional complex': ['APEX1', 'STAT3', 'HIF1A', 'CITED1'],
#  'IRF3-CBP complex': ['IRF3', 'CITED1'],
#  'PC2 complex': ['MED7',
#   'MED14',
#   'MED24',
#   'MED6',
#   'MED21',
#   'MED27',
#   'MED10',
#   'MED20',
#   'MED17',
#   'THRAP3',
#   'MED16',
#   'MED31'],
#  'INO80 chromatin remodeling complex': ['ACTL6A',
#   'TCF3',
#   'INO80D',
#   'NFRKB',
#   'INO80C',
#   'INO80E',
#   'MCRS1',
#   'INO80B',
#   'ACTR8',
#   'ACTR5',
#   'INO80',
#   'RUVBL2',
#   'RUVBL1'],
#  'SRCAP-associated chromatin remodeling complex': ['ZNHIT1',
#   'YEATS4',
#   'ACTL6A',
#   'H2AFZ',
#   'VPS72',
#   'SRCAP',
#   'EAF2',
#   'ACTR6',
#   'RUVBL2',
#   'RUVBL1'],
#  '40S ribosomal subunit, cytoplasmic': ['RPS17',
#   'RPSA',
#   'RPS2',
#   'RPS3',
#   'RPS12',
#   'RPS19',
#   'RPS9',
#   'RPS5',
#   'RPS10',
#   'RPS20',
#   'RPS3A',
#   'RPS7',
#   'RPS8',
#   'RPS15A',
#   'RPS16',
#   'RPS14',
#   'RPS23',
#   'RPS18',
#   'RPS29',
#   'RPS13',
#   'RPS11',
#   'RPS4X',
#   'RPS6',
#   'RPS15',
#   'RPS24',
#   'RPS25',
#   'RPS26',
#   'RPS28',
#   'FAU',
#   'RPS27A',
#   'RPS21'],
#  'Ribosome, cytoplasmic': ['RPLP1',
#   'RPLP2',
#   'RPLP0',
#   'RPS17',
#   'RPSA',
#   'RPS2',
#   'RPL35A',
#   'RPL7',
#   'RPL17',
#   'RPS4Y1',
#   'RPS3',
#   'RPS12',
#   'RPL13',
#   'RPL10',
#   'RPL12',
#   'RPL9',
#   ' RPL9',
#   'RPL22',
#   'RPL4',
#   'RPS19',
#   'RPL3',
#   'RPL13A',
#   'RPS27',
#   'RPL35',
#   'RPL27A',
#   'RPL5',
#   'RPL21',
#   'RPL28',
#   'RPS9',
#   'RPS5',
#   'RPS10',
#   'RPL29',
#   'RPL34',
#   'RPL14',
#   'RPS20',
#   'RPS3A',
#   'RPL26',
#   'RPL15',
#   'RPL27',
#   'RPL37A',
#   'RPL37',
#   'RPS7',
#   'RPS8',
#   'RPS15A',
#   'RPS16',
#   'RPS14',
#   'RPS23',
#   'RPS18',
#   'RPS29',
#   'RPS13',
#   'RPS11',
#   'RPL7A',
#   'RPS4X',
#   'RPL23A',
#   'RPS6',
#   'RPL23',
#   'RPS15',
#   'RPS24',
#   'RPS25',
#   'RPS26',
#   'RPS28',
#   'FAU',
#   'RPL30',
#   'RPL39',
#   'RPL31',
#   'RPL10A',
#   'RPL32',
#   'RPL11',
#   'RPL8',
#   'RPL41',
#   'RPS27A',
#   'UBA52',
#   'RPL38',
#   'RPS21',
#   'RPL24',
#   'RPL36A',
#   'RPL19',
#   'RPL18A',
#   'RPL6',
#   'RPL18',
#   'RPL36'],
#  '60S ribosomal subunit, cytoplasmic': ['RPLP1',
#   'RPLP2',
#   'RPLP0',
#   'RPL35A',
#   'RPL7',
#   'RPL17',
#   'RPL13',
#   'RPL10',
#   'RPL12',
#   'RPL9',
#   ' RPL9',
#   'RPL22',
#   'RPL4',
#   'RPL3',
#   'RPL13A',
#   'RPL35',
#   'RPL27A',
#   'RPL5',
#   'RPL21',
#   'RPL28',
#   'RPL29',
#   'RPL34',
#   'RPL14',
#   'RPL26',
#   'RPL15',
#   'RPL27',
#   'RPL37A',
#   'RPL37',
#   'RPL7A',
#   'RPL23A',
#   'RPL23',
#   'RPL30',
#   'RPL39',
#   'RPL31',
#   'RPL10A',
#   'RPL32',
#   'RPL11',
#   'RPL8',
#   'RPL41',
#   'UBA52',
#   'RPL38',
#   'RPL24',
#   'RPL36A',
#   'RPL19',
#   'RPL18A',
#   'RPL6',
#   'RPL18',
#   'RPL36'],
#  'Cell cycle kinase complex CDC2': ['CCNB2',
#   'CDK1',
#   'PCNA',
#   'CCNB1',
#   'CCND1',
#   'CDKN1A'],
#  'Cell cycle kinase complex CDK2': ['PCNA', 'CCND1', 'CDK2', 'CDKN1A'],
#  'Cell cycle kinase complex CDK4': ['CDK4', 'PCNA', 'CCND1', 'CDKN1A'],
#  'Cell cycle kinase complex CDK5': ['PCNA',
#   'CCND1',
#   'CCND3',
#   'CDKN1A',
#   'CDK5'],
#  'PCNA-p21 complex': ['PCNA', 'CDKN1A'],
#  '28S ribosomal subunit, mitochondrial': ['MRPS12',
#   'MRPS14',
#   'DAP3',
#   'MRPS22',
#   'MRPS25',
#   'MRPS10',
#   'MRPS35',
#   'MRPS5',
#   'MRPS36',
#   'MRPS11',
#   'MRPS15',
#   'MRPS21',
#   'MRPS34',
#   'MRPS6',
#   'MRPS9',
#   'MRPS27',
#   'MRPS31',
#   'MRPS24',
#   'MRPS26',
#   'MRPS30',
#   'MRPS18A',
#   'MRPS33',
#   'MRPS28',
#   'MRPS17',
#   'MRPS7',
#   'MRPS2',
#   'MRPS16',
#   'MRPS18C',
#   'MRPS23',
#   'MRPS18B'],
#  '55S ribosome, mitochondrial': ['MRPS12',
#   'MRPS14',
#   'MRPL33',
#   'MRPL3',
#   'MRPL19',
#   'DAP3',
#   'MRPL12',
#   'MRPS22',
#   'MRPS25',
#   'MRPS10',
#   'MRPS35',
#   'MRPS5',
#   'MRPS36',
#   'MRPS11',
#   'MRPS15',
#   'MRPS21',
#   'MRPS34',
#   'MRPS6',
#   'MRPS9',
#   'LACTB',
#   'MRPL28',
#   'MRPL49',
#   'MRPL23',
#   'MRPL51',
#   'MRPL2',
#   'MRPL54',
#   'MRPL14',
#   'MRPL21',
#   'MRPL55',
#   'MRPL10',
#   'MRPL52',
#   'MRPL41',
#   'MRPL50',
#   'MRPL43',
#   'MRPL30',
#   'MRPS27',
#   'MRPS31',
#   'MRPL24',
#   'MRPL38',
#   'MRPS24',
#   'MRPL53',
#   'MRPL48',
#   'MRPL34',
#   'MRPL45',
#   'MRPL32',
#   'MRPL20',
#   'MRPL13',
#   'MRPL9',
#   'MRPL4',
#   'MRPL1',
#   'MRPS26',
#   'MRPL37',
#   'MRPL18',
#   'MRPL46',
#   'MRPL44',
#   'MRPL47',
#   'MRPS30',
#   'MRPL40',
#   'MRPL17',
#   'MRPS18A',
#   'MRPL22',
#   'MRPL16',
#   'MRPL39',
#   'MRPL35',
#   'MRPL15',
#   'MRPL36',
#   'MRPL27',
#   'MRPS33',
#   'MRPS28',
#   'MRPS17',
#   'MRPS7',
#   'MRPS2',
#   'MRPL11',
#   'MRPS16',
#   'MRPS18C',
#   'MRPS23',
#   'MRPS18B',
#   'MRPL42'],
#  'DNA-PK-Ku complex': ['XRCC6', 'XRCC5', 'PRKDC'],
#  '39S ribosomal subunit, mitochondrial': ['MRPL33',
#   'MRPL3',
#   'MRPL19',
#   'MRPL12',
#   'LACTB',
#   'MRPL28',
#   'MRPL49',
#   'MRPL23',
#   'MRPL51',
#   'MRPL2',
#   'MRPL54',
#   'MRPL14',
#   'MRPL21',
#   'MRPL55',
#   'MRPL10',
#   'MRPL52',
#   'MRPL41',
#   'MRPL50',
#   'MRPL43',
#   'MRPL30',
#   'MRPL24',
#   'MRPL38',
#   'MRPL53',
#   'MRPL48',
#   'MRPL34',
#   'MRPL45',
#   'MRPL32',
#   'MRPL20',
#   'MRPL13',
#   'MRPL9',
#   'MRPL4',
#   'MRPL1',
#   'MRPL37',
#   'MRPL18',
#   'MRPL46',
#   'MRPL44',
#   'MRPL47',
#   'MRPL40',
#   'MRPL17',
#   'MRPL22',
#   'MRPL16',
#   'MRPL39',
#   'MRPL35',
#   'MRPL15',
#   'MRPL36',
#   'MRPL27',
#   'MRPL11',
#   'MRPL42'],
#  'Ku antigen complex': ['XRCC6', 'XRCC5'],
#  'PSF-p54(nrb) complex': ['SFPQ', 'NONO'],
#  'p54(nrb)-PSF-matrin3 complex': ['SFPQ', 'MATR3', 'NONO'],
#  'DNA ligase IV-XRCC4-AHNK complex': ['LIG4', 'AHNAK', 'XRCC4'],
#  'Sarcoglycan-sarcospan complex SG-SPN': ['SGCG',
#   'SSPN',
#   'SGCB',
#   'SGCA',
#   'SGCD'],
#  'DNA ligase IV-XRCC4-PNK complex': ['LIG4', 'XRCC4', 'PNKP'],
#  'Spliceosome': ['IGF2BP3',
#   'DDX3X',
#   'TCERG1',
#   'U2SURP',
#   'PPM1G',
#   'DHX15',
#   'PRPF4',
#   'SART1',
#   'PRPF3',
#   'PPIH',
#   'PLRG1',
#   'ZNF207',
#   'HTATSF1',
#   'NUDT21',
#   'DHX16',
#   'AQR',
#   'CDC40',
#   'PRPF40A',
#   'SF3B1',
#   'SNRNP200',
#   'BCAS2',
#   'DNAJC8',
#   'SMNDC1',
#   'PRPF6',
#   'LUC7L3',
#   'SLU7',
#   'CD2BP2',
#   'SYF2',
#   'SNRPB2',
#   'SNRNP70',
#   'SNRPA',
#   'SNRPC',
#   'SNRPA1',
#   'PABPC1',
#   'SNRPB',
#   'DDX5',
#   'U2AF2',
#   'EIF4A3',
#   'BUD31',
#   'MTREX',
#   'RBM25',
#   'NCBP2',
#   'MFAP1',
#   'SNU13',
#   'MAGOH',
#   'SNRPE',
#   'SNRPF',
#   'SNRPG',
#   'LSM3',
#   'LSM6',
#   'SNRPD1',
#   'SNRPD2',
#   'SNRPD3',
#   'TRA2B',
#   'TXNL4A',
#   'SRSF3',
#   'U2AF1',
#   'SRSF2',
#   'SRSF11',
#   'SRSF1',
#   'SRSF4',
#   'DHX9',
#   'NCBP1',
#   'SF3A3',
#   'IK',
#   'SRSF9',
#   'SRSF5',
#   'SRSF6',
#   'PPIL2',
#   'SF3B2',
#   'PRPF4B',
#   'SNW1',
#   'THOC5',
#   'DDX39B',
#   'CIRBP',
#   'RBM39',
#   'DHX8',
#   'WTAP',
#   'EFTUD2',
#   'RNPS1',
#   'SF3B3',
#   'SF3B4',
#   'SF3A2',
#   'SF3A1',
#   'SF1',
#   'SRSF7',
#   'CPSF6',
#   'SMU1',
#   'FNBP3',
#   'USP39',
#   'KIAA1429',
#   'THOC7',
#   'PRPF8',
#   'DDX46',
#   'ALYREF',
#   'THOC6',
#   'SRRM1',
#   'THOC2',
#   'CACTIN',
#   'SNRNP27',
#   'PRPF31',
#   'CTNNBL1',
#   'DHX38',
#   'DDX17',
#   'PPWD1',
#   'DGCR14',
#   'SNRNP40',
#   'THOC1',
#   'RBM17',
#   'THOC3',
#   'RBM15',
#   'SPEN',
#   'CDC5L',
#   'PRPF18',
#   'C19orf43',
#   'BUD13',
#   'DDX23',
#   'SRRT',
#   'CRNKL1',
#   'PPIL3',
#   'MOV10',
#   'CWC22',
#   'XAB2',
#   'RBM22',
#   'CDK12',
#   'CWC15',
#   'TFIP11',
#   'PUF60',
#   'DDX41',
#   'LSM7',
#   'ACIN1',
#   'ISY1',
#   'PRPF19',
#   'PPIE',
#   'SRRM2',
#   'WBP11',
#   'LSM2',
#   'SF3B6',
#   'PPIL1',
#   'LSM4',
#   'PAXBP1',
#   'RBM8A',
#   'CFAP20'],
#  'DNA ligase IV-condensin complex': ['SMC2', 'LIG4', 'SMC4'],
#  'DNA ligase IV-XRCC4-XLF complex': ['LIG4', 'XRCC4', 'NHEJ1'],
#  'Artemis-DNA-PK complex': ['PRKDC', 'DCLRE1C'],
#  'DNA ligase III-XRCC1-PNK-DNA-pol III multiprotein complex': ['POLB',
#   'XRCC1',
#   'LIG3',
#   'PNKP'],
#  'ERCC1-ERCC4-MSH2 complex': ['ERCC1', 'MSH2', 'ERCC4'],
#  'MSH2-MSH6-PMS2-MLH1 complex': ['MLH1', 'MSH2', 'MSH6', 'PMS2'],
#  'MSH2-MSH6-PMS1-MLH1 complex': ['MLH1', 'MSH2', 'MSH6', 'PMS1'],
#  'MSH2-MSH6 complex': ['MSH2', 'MSH6'],
#  'MSH2-MSH3 complex': ['MSH3', 'MSH2'],
#  'PCNA-MutS-alpha-MutL-alpha-DNA complex': ['PCNA',
#   'MLH1',
#   'MSH2',
#   'MSH6',
#   'PMS2'],
#  'MutL-beta complex': ['MLH1', 'PMS1'],
#  'Ubiquitin E3 ligase (UBADC1, RNF123)': ['RNF123', 'UBAC1'],
#  'MCM complex': ['MCM3', 'MCM4', 'MCM5', 'MCM7', 'MCM2', 'MCM6'],
#  'ORC complex (origin recognition complex)': ['ORC5',
#   'ORC4',
#   'ORC1',
#   'ORC2',
#   'ORC3',
#   'ORC6'],
#  'Ubiquitin E3 ligase (SKP1A, FBXW2, CUL1)': ['SKP1', 'CUL1', 'FBXW2'],
#  'Ubiquitin E3 ligase (DDB1, CUL4A, RBX1)': ['RBX1', 'CUL4A', 'DDB1'],
#  'Succinyl-CoA synthetase, GDP-forming': ['SUCLG1', 'SUCLG2'],
#  'Succinyl-CoA synthetase, ADP-forming': ['SUCLG1', 'SUCLA2'],
#  'Isocitrate dehydrogenase [NADP], cytoplasmic': ['IDH1'],
#  'Guanylyl cyclase, soluble (GUCY1A2, GUCY1B3)': ['GUCY1A2', 'GUCY1B3'],
#  'Guanylyl cyclase, soluble (GUCY1A3, GUCY1B3)': ['GUCY1A3', 'GUCY1B3'],
#  'EXO1-MLH1-PMS2 complex': ['MLH1', 'PMS2', 'EXO1'],
#  'Farnesyltransferase': ['FNTA', 'FNTB'],
#  'Beta-dystroglycan-caveolin-3 complex': ['CAV3', 'DAG1'],
#  'EXO1-MLH1-PCNA complex': ['PCNA', 'MLH1', 'EXO1'],
#  'MSH4-MSH5-GPS2 complex': ['MSH4', 'MSH5', 'GPS2'],
#  'Meprin A': ['MEP1A', 'MEP1B'],
#  'Molybdopterin synthase': ['MOCS2', 'MOCS2'],
#  'Phosphatidylinositol 3-kinase complex (PIK3C3, PIK3R4)': ['PIK3C3',
#   'PIK3R4'],
#  '18S U11/U12 snRNP': ['DHX15',
#   'SF3B1',
#   'SNRPB',
#   'SNRPE',
#   'SNRPF',
#   'SNRPG',
#   'SNRPD1',
#   'SNRPD2',
#   'SNRPD3',
#   'YBX1',
#   'SF3B2',
#   'SF3B3',
#   'SF3B4',
#   'ZRSR2',
#   'SNRNP35',
#   'SNRNP48',
#   'PRPF8',
#   'PDCD7',
#   'ZCRB1',
#   'RNPC3',
#   'SNRNP25',
#   'SF3B5',
#   'ZMAT5',
#   'SF3B6'],
#  'N-NOS-CHIP-HSP70-1 complex': ['HSPA1A', 'NOS1', 'STUB1'],
#  'BASC complex (BRCA1-associated genome surveillance complex)': ['NBN',
#   'RFC4',
#   'RFC2',
#   'RFC1',
#   'BRCA1',
#   'MLH1',
#   'MSH2',
#   'MRE11A',
#   'MSH6',
#   'BLM',
#   'ATM',
#   'RAD50'],
#  'BASC (Ab 80) complex (BRCA1-associated genome surveillance complex)': ['RFC4',
#   'RFC2',
#   'RFC1',
#   'BRCA1',
#   'MLH1',
#   'MSH2',
#   'MSH6',
#   'BLM'],
#  'BASC (Ab 81) complex (BRCA1-associated genome surveillance complex)': ['RFC4',
#   'RFC2',
#   'RFC1',
#   'BRCA1',
#   'MLH1',
#   'ATM'],
#  'BASC (Ab C-20) complex (BRCA1-associated genome surveillance complex)': ['BRCA1',
#   'MSH6',
#   'RAD50'],
#  'GCN5-TRRAP histone acetyltransferase complex': ['SUPT3H',
#   'TADA3',
#   'TAF5L',
#   'BRCA1',
#   'MSH2',
#   'MSH6',
#   'TAF10',
#   'TAF9',
#   'KAT2A',
#   'TRRAP'],
#  'TFTC-type histone acetyl transferase complex': ['MED14',
#   'MED24',
#   'ESR1',
#   'MED1',
#   'KAT2A',
#   'MED12',
#   'MED17',
#   'MED13',
#   'MED23',
#   'MED16',
#   'TRRAP'],
#  'BP-SMAD complex': ['BACH1',
#   'SMAD9',
#   'GJB6',
#   'PSMC3',
#   'ERCC3',
#   'MXI1',
#   'KLF10',
#   'TGFBI'],
#  'TFTC complex (TATA-binding protein-free TAF-II-containing complex)': ['TAF4',
#   'ATXN7',
#   'SUPT3H',
#   'TADA3',
#   'TAF5L',
#   'TAF6',
#   'TAF10',
#   'SF3B3',
#   'TAF5',
#   'TAF7',
#   'TAF12',
#   'TAF9',
#   'TAF2',
#   'KAT2A',
#   'TAF9B',
#   'TRRAP',
#   'TAF6L'],
#  'CRB1-MPP5-INADL complex': ['CRB1', 'MPP5', 'PATJ'],
#  'MPP4-MPP5-CRB1 complex': ['CRB1', 'MPP5', 'MPP4'],
#  'Gamma-secretase complex (APH1B, PSEN2, PSENEN, NCSTN)': ['PSEN2',
#   'APH1B',
#   'NCSTN',
#   'PSENEN'],
#  'Gamma-secretase complex (APH1A, PSEN2, PSENEN, NCSTN)': ['PSEN2',
#   'NCSTN',
#   'APH1A',
#   'PSENEN'],
#  'TFIID-beta complex': ['TAF4',
#   'TBP',
#   'TAF1',
#   'TAF6',
#   'TAF10',
#   'TAF5',
#   'TAF13',
#   'TAF11',
#   'TAF7',
#   'TAF12',
#   'TAF9',
#   'TAF9B'],
#  'PCAF complex': ['TADA2A',
#   'SUPT3H',
#   'TADA3',
#   'TAF5L',
#   'TAF10',
#   'TAF12',
#   'TAF9',
#   'KAT2B',
#   'TRRAP',
#   'TAF6L'],
#  'Prolyl 4-hydroxylase (alpha(I)-type)': ['P4HB', 'P4HA1'],
#  'Prolyl 4-hydroxylase (alpha(III)-type)': ['P4HB', 'P4HA3'],
#  'STAGA complex': ['ATXN7',
#   'SUPT3H',
#   'TADA3',
#   'TAF5L',
#   'SUPT7L',
#   'TAF10',
#   'SF3B3',
#   'TAF12',
#   'TAF9',
#   'KAT2A',
#   'TADA1',
#   'TRRAP',
#   'TAF6L'],
#  'STAGA core complex': ['SUPT3H', 'TAF9', 'KAT2A'],
#  'TFIID complex, B-cell specific': ['TAF4',
#   'TBP',
#   'TAF1',
#   'TAF6',
#   'TAF10',
#   'TAF5',
#   'TAF13',
#   'TAF11',
#   'TAF7',
#   'TAF12',
#   'TAF9',
#   'TAF4B'],
#  'WIP-WASp-actin-myosin-IIa complex': ['WIPF1',
#   'MYL12A',
#   'MYH9',
#   'WAS',
#   'MYL6',
#   'ACTA2'],
#  'TFIIA complex': ['GTF2A1', 'GTF2A2'],
#  'DA complex': ['TAF4',
#   'TBP',
#   'TAF1',
#   'TAF6',
#   'GTF2A1',
#   'GTF2A2',
#   'TAF10',
#   'TAF5',
#   'TAF13',
#   'TAF11',
#   'TAF7',
#   'TAF12',
#   'TAF9',
#   'TAF3',
#   'TAF2'],
#  'DAB complex': ['TAF4',
#   'TBP',
#   'TAF1',
#   'TAF6',
#   'GTF2A1',
#   'GTF2A2',
#   'GTF2B',
#   'TAF10',
#   'TAF5',
#   'TAF13',
#   'TAF11',
#   'TAF7',
#   'TAF12',
#   'TAF9',
#   'TAF3',
#   'TAF2'],
#  'TAF4-TAF12 subcomplex of TFIID complex': ['TAF4', 'TAF12'],
#  'AKAP5-PRKAR2A-PPP3CA complex': ['PRKAR2A', 'AKAP5', 'PPP3CA'],
#  'AKAP250-PKA-PDE4D complex': ['PRKACA', 'AKAP12', 'PDE4D'],
#  'AMY-1-S-AKAP84-RII-beta complex': ['PRKAR2B', 'AKAP1', 'MYCBP'],
#  'KCNQ1 macromolecular complex': ['PRKAR2A',
#   'PRKACA',
#   'KCNQ1',
#   'PPP1CA',
#   'AKAP9'],
#  'Polycystin-1-E-cadherin-beta-catenin complex': ['CDH1', 'CTNNB1', 'PKD1'],
#  'Polycystin-1-E-cadherin-beta-catenin-Flotillin-2 complex': ['CDH1',
#   'CTNNB1',
#   'PKD1',
#   'FLOT2'],
#  'TIP60 histone acetylase complex': ['ACTL6A',
#   'KAT5',
#   'RUVBL2',
#   'RUVBL1',
#   'TRRAP'],
#  'TRPC3-TRPC4 channel complex, redox-sensitive': ['TRPC3', 'TRPC4'],
#  'NuA4/Tip60-HAT complex': ['YEATS4',
#   'ACTL6A',
#   'MORF4L2',
#   'VPS72',
#   'KAT5',
#   'EP400',
#   'BRD8',
#   'EPC1',
#   'MEAF6',
#   'DMAP1',
#   'MRGBP',
#   'ING3',
#   'MORF4L1',
#   'RUVBL2',
#   'RUVBL1',
#   'TRRAP'],
#  'XPA-ERCC1-ERCC4 complex': ['ERCC1', 'XPA', 'ERCC4'],
#  'IMP3-IMP4-MPP10 complex': ['MPHOSPH10', 'IMP4', 'IMP3'],
#  'TRPC1-TRPC3-TRPC7 complex': ['TRPC1', 'TRPC3', 'TRPC7'],
#  'IGF1-IGFBP3-ALS complex': ['IGF1', 'IGFBP3', 'IGFALS'],
#  'DRIP complex': ['MED7',
#   'MED14',
#   'MED24',
#   'MED6',
#   'MED26',
#   'VDR',
#   'RXRB',
#   'MED1',
#   'MED12',
#   'MED4',
#   'MED17',
#   'MED13',
#   'MED23',
#   'MED16'],
#  'NOS3-CAV1-NOSTRIN complex': ['NOS3', 'CAV1', 'NOSTRIN'],
#  'core-histone (H2A/H2B/H3/H4)-TDIF2-TDT complex': ['DNTT',
#   'HIST1H4A',
#   '',
#   'HIST1H3A',
#   '',
#   'HIST2H2AC',
#   'HIST2H2BE',
#   'DNTTIP2'],
#  'IFNAR1-IFNAR2-IFNB1 complex': ['IFNB1', 'IFNAR1', 'IFNAR2'],
#  'RHOA-IP3R-TRPC1 complex': ['TRPC1', 'RHOA', 'ITPR1'],
#  'TRP1-G alpha-11-IP3R3-CAV1 signaling complex': ['GNA11',
#   'TRPC1',
#   'CAV1',
#   'ITPR3'],
#  'Channel complex TRPM6-TRPM7': ['TRPM7', 'TRPM6'],
#  'Decapping complex': ['DDX6', 'EDC4', 'DCP2', 'EDC3', 'DCP1A'],
#  'LSm1-7 complex': ['LSM1', 'LSM3', 'LSM6', 'LSM7', 'LSM2', 'LSM5', 'LSM4'],
#  'LSm2-8 complex': ['LSM8', 'LSM3', 'LSM6', 'LSM7', 'LSM2', 'LSM5', 'LSM4'],
#  'F1F0-ATP synthase, mitochondrial': ['ATP5H',
#   'ATP5L',
#   'MT-ATP6',
#   'MT-ATP8',
#   'ATP5G1',
#   'ATP5B',
#   'ATP5J',
#   'ATP5F1',
#   'ATP5A1',
#   'ATP5D',
#   'ATP5C1',
#   'ATP5O',
#   'ATP5J2',
#   'ATP5E',
#   'ATP5I',
#   'ATPIF1'],
#  'p300-CBP-p270-SWI/SNF complex': ['ARID1A',
#   'SMARCA4',
#   'EP300',
#   'SMARCB1',
#   'SMARCC2',
#   'CREBBP',
#   'SMARCC1'],
#  'p300-CBP-p270 complex': ['ARID1A', 'EP300', 'CREBBP'],
#  'ABIN2-NFKB1-MAP3K8 complex': ['NFKB1', 'MAP3K8', 'TNIP2'],
#  'FHL2-p53-HIPK2 complex': ['TP53', 'FHL2', 'HIPK2'],
#  'Mi2/NuRD-BCL6-MTA3 complex': ['MBD3', 'BCL6', 'HDAC1', 'CHD4', 'MTA3'],
#  'NuRD.1 complex': ['MBD3',
#   'RBBP4',
#   'MTA1',
#   'CHD4',
#   'RBBP7',
#   'HDAC1',
#   'HDAC2',
#   'MTA3'],
#  'SAP complex (Sin3-associated protein complex)': ['SAP30',
#   'RBBP4',
#   'HDAC1',
#   'RBBP7',
#   'ARID4B',
#   'HDAC2',
#   'SIN3A',
#   'SAP130',
#   'SUDS3'],
#  'Kv4.2-DPP10 channel complex': ['DPP10', 'KCND2'],
#  'SIN3-HDAC-SAP30-ARID4 complex': ['SAP30',
#   'RBBP4',
#   'HDAC1',
#   'RBBP7',
#   'ARID4B',
#   'HDAC2',
#   'SIN3A'],
#  'TIM (TIM17A, TIM17B, TIM23, TIM44) complex, mitochondrial': ['TIMM23',
#   'TIMM44',
#   'TIMM17B',
#   'TIMM17A'],
#  'MSL complex': ['MSL1', 'MSL3', 'KAT8', 'MSL2'],
#  'CTF18-CTF8-DCC1 complex': ['CHTF8', 'CHTF18', 'DSCC1'],
#  'CTF18-CTF8-DCC1-RFC3 complex': ['CHTF8', 'RFC3', 'CHTF18', 'DSCC1'],
#  'NRD complex (Nucleosome remodeling and deacetylation complex)': ['KDM1A',
#   'RBBP4',
#   'CHD3',
#   'MTA1',
#   'HDAC1',
#   'CHD4',
#   'HDAC2'],
#  'CASK-LIN7C-APBA1 complex': ['CASK', 'APBA1', 'LIN7C'],
#  'MRE11A-RAD50-NBN-TRF2 complex': ['NBN', 'MRE11A', 'TERF2', 'RAD50'],
#  'CoREST-HDAC complex': ['KDM1A',
#   'ZNF217',
#   'HDAC1',
#   'HDAC2',
#   'PHF21A',
#   'HMG20B',
#   'RCOR1'],
#  'Ubiquitin E3 ligase (VHL, TCEB1, TCEB2, CUL2)': ['VHL',
#   'CUL2',
#   'TCEB1',
#   'TCEB2'],
#  'TIM (TIM9, TIM10) complex, mitochondrial': ['TIMM10', 'TIMM9'],
#  'LSD1-CoREST complex': ['KDM1A', 'RCOR1'],
#  'LSD1 complex': ['KDM1A',
#   'ZNF217',
#   'HSPA1A',
#   'HSPA1B',
#   'CTBP1',
#   'HDAC1',
#   'RREB1',
#   'PHF21A',
#   'PHF21B',
#   'HMG20A',
#   'HMG20B',
#   'RCOR3',
#   'ZMYM2',
#   'RCOR1'],
#  'MRN-TRRAP complex (MRE11A-RAD50-NBN-TRRAP complex)': ['NBN',
#   'MRE11A',
#   'RAD50',
#   'TRRAP'],
#  'BLM-TRF2 complex': ['BLM', 'TERF2'],
#  'Tacc1-chTOG-AuroraA  complex': ['AURKA', 'TACC1', 'CKAP5'],
#  'Anti-HDAC2 complex': ['KDM1A',
#   'MTA2',
#   'GTF2I',
#   'RBBP4',
#   'CHD3',
#   'MTA1',
#   'HDAC1',
#   'ZMYM3',
#   'GSE1',
#   'CHD4',
#   'RBBP7',
#   'HDAC2',
#   'PHF21A',
#   'SIN3A',
#   'HMG20B',
#   'ZMYM2',
#   'RCOR1'],
#  'anti-BHC110 complex': ['KDM1A',
#   'ZNF217',
#   'GTF2I',
#   'HDAC1',
#   'ZMYM3',
#   'GSE1',
#   'HDAC2',
#   'PHF21A',
#   'HMG20B',
#   'ZMYM2',
#   'RCOR1'],
#  'XFIM complex': ['KDM1A', 'GTF2I', 'HDAC1', 'ZMYM3', 'HDAC2'],
#  'AGPS-GNPAT complex': ['AGPS', 'GNPAT'],
#  'BHC complex': ['KDM1A', 'HDAC1', 'HDAC2', 'PHF21A', 'HMG20B', 'RCOR1'],
#  'RANBPM-Muskelin-TWA1-HSMpp8 complex': ['RANBP9',
#   'MPHOSPH8',
#   'GID8',
#   'MKLN1'],
#  'RANBPM-SMP1 complex': ['TMEM50A', 'RANBP9'],
#  'CtBP complex': ['CBX4',
#   'ZEB2',
#   'KDM1A',
#   'ZNF217',
#   'ZEB1',
#   'CTBP2',
#   'CTBP1',
#   'HDAC1',
#   'ZNF516',
#   'RREB1',
#   'HDAC2',
#   'LCOR',
#   'EHMT2',
#   'EHMT1',
#   'RCOR3',
#   'RCOR1',
#   'CDYL'],
#  'CtBP core complex': ['KDM1A',
#   'ZEB1',
#   'CTBP2',
#   'CTBP1',
#   'HDAC1',
#   'HDAC2',
#   'EHMT2',
#   'EHMT1',
#   'RCOR1'],
#  'ASPP1-SAM68 complex': ['KHDRBS1', 'PPP1R13B'],
#  'HDAC1-associated protein complex': ['KDM1A',
#   'MTA2',
#   'MBD3',
#   'RBBP4',
#   'CHD3',
#   'HDAC1',
#   'RBBP7',
#   'MBD2',
#   'RCOR1'],
#  'HDAC1-associated core complex cI': ['KDM1A', 'HDAC1', 'RCOR1'],
#  'HDAC1-associated core complex cII': ['MTA2',
#   'MBD3',
#   'RBBP4',
#   'CHD3',
#   'HDAC1',
#   'RBBP7',
#   'GATAD2A',
#   'MBD2',
#   'RCOR1'],
#  'HDAC2-asscociated core complex': ['MTA2',
#   'MBD3',
#   'RBBP4',
#   'CHD3',
#   'RBBP7',
#   'GATAD2A',
#   'HDAC2'],
#  'AP3-BLOC1 complex': ['AP3B1',
#   'AP3D1',
#   'SNAPIN',
#   'AP3M2',
#   'AP3S2',
#   'BLOC1S1',
#   'AP3B2',
#   'BLOC1S3',
#   'BLOC1S2',
#   'BLOC1S5',
#   'AP3S1',
#   'DTNBP1',
#   'BLOC1S4',
#   'BLOC1S6',
#   'AP3M1'],
#  'BLOC1-BLOC2 complex': ['SNAPIN',
#   'BLOC1S1',
#   'BLOC1S3',
#   'BLOC1S2',
#   'HPS6',
#   'BLOC1S5',
#   'HPS3',
#   'DTNBP1',
#   'BLOC1S4',
#   'BLOC1S6',
#   'HPS5'],
#  'HSF1-HSF2 complex': ['HSF1', 'HSF2'],
#  'VPS35-VPS29-VPS26A complex': ['VPS26A', 'VPS35', 'VPS29'],
#  'Retromer complex (SNX1, SNX2, VPS35, VPS29, VPS26A)': ['SNX2',
#   'VPS26A',
#   'SNX1',
#   'VPS35',
#   'VPS29'],
#  'BKCA-beta2AR-AKAP79 signaling complex': ['ADRB2', 'AKAP5', 'KCNMA1'],
#  'BKCA-beta2AR complex': ['ADRB2', 'KCNMA1'],
#  'GINS complex': ['GINS1', 'GINS4', 'GINS3', 'GINS2'],
#  'RANBMP-CD39 complex': ['RANBP1', 'ENTPD1'],
#  'C-CFTR-NHERF-ezrin complex': ['SLC9A3R1', 'CFTR', 'EZR'],
#  'PAX9-MSX1 complex': ['MSX1', 'PAX9'],
#  'CFTR-NHERF-beta(2)AR signaling complex': ['SLC9A3R1', 'ADRB2', 'CFTR'],
#  'SIN3-SAP25 complex': ['SAP18',
#   'SAP30',
#   'RBBP4',
#   'HDAC1',
#   'RBBP7',
#   'Sap25',
#   'ARID4B',
#   'HDAC2',
#   'SIN3A',
#   'SAP130',
#   'SUDS3'],
#  'BRMS1-SIN3-HDAC complex': ['SIN3B',
#   'SAP30',
#   'RBBP4',
#   'HDAC1',
#   'RBBP7',
#   'HDAC2',
#   'SIN3A',
#   'BRMS1'],
#  'BRMS1-RBP1 complex': ['ARID4B', 'BRMS1'],
#  'ARD1-NATH complex': ['TRIM23', 'NAA15'],
#  'SNARE complex (RINT1, ZW10, p31)': ['ZW10', 'PSMD8', 'RINT1'],
#  'SNARE complex (HGS, SNAP25, STX13)': ['HGS', 'SNAP25', 'STX12'],
#  'SNARE complex (VAMP2, SNAP25, STX13)': ['SNAP25', 'VAMP2', 'STX12'],
#  'Brg1-associated complex I': ['ARID1A',
#   'PRMT5',
#   'ACTL6A',
#   'SMARCA4',
#   'SMARCB1',
#   'SMARCC2',
#   'SMARCC1',
#   'SMARCE1',
#   'SMARCD1'],
#  'Brm-associated complex': ['ARID1A',
#   'PRMT5',
#   'ACTL6A',
#   'SMARCA2',
#   'SMARCB1',
#   'SMARCC2',
#   'SMARCC1',
#   'SMARCE1',
#   'SMARCD1'],
#  'BRG1-SIN3A complex': ['ARID1A',
#   'PRMT5',
#   'ACTL6A',
#   'SMARCA4',
#   'RBBP4',
#   'SMARCB1',
#   'SMARCD3',
#   'SMARCC2',
#   'HDAC2',
#   'SMARCC1',
#   'SMARCD2',
#   'SMARCE1',
#   'SMARCD1',
#   'SIN3A'],
#  'BRM-SIN3A complex': ['ARID1A',
#   'PRMT5',
#   'ACTL6A',
#   'SMARCA2',
#   'RBBP4',
#   'SMARCB1',
#   'HDAC1',
#   'SMARCD3',
#   'SMARCC2',
#   'HDAC2',
#   'SMARCC1',
#   'SMARCD2',
#   'SMARCE1',
#   'SMARCD1',
#   'SIN3A'],
#  'PU.1-SIN3A-HDAC complex': ['SPI1', 'HDAC1', 'SIN3A'],
#  'PU.1-TBP complex': ['SPI1', 'TBP'],
#  'MRG15-PAM14-RB complex': ['RB1', 'MORF4L1', 'MRFAP1'],
#  'MAF2 complex': ['KAT8', 'MORF4L1'],
#  'P2X7 receptor signalling complex': ['ACTN4',
#   'SVIL',
#   'ITGB2',
#   'HSP90AB1',
#   'HSPA1A',
#   'HSPA8',
#   'PTPRB',
#   'PI4KA',
#   'ACTB',
#   'MPP3',
#   'LAMA3',
#   'P2RX7'],
#  'DDB2 complex': ['COPS2',
#   'RBX1',
#   'GPS1',
#   'CUL4A',
#   'DDB1',
#   'COPS6',
#   'DDB2',
#   'COPS5',
#   'COPS8',
#   'COPS4',
#   'COPS7A',
#   'COPS3'],
#  'CSA complex': ['COPS2',
#   'RBX1',
#   'GPS1',
#   'ERCC8',
#   'CUL4A',
#   'DDB1',
#   'COPS6',
#   'COPS5',
#   'COPS8',
#   'COPS4',
#   'COPS7A',
#   'COPS3'],
#  'CSA-POLIIa complex': ['POLR2A',
#   'COPS2',
#   'RBX1',
#   'GPS1',
#   'ERCC8',
#   'CUL4A',
#   'DDB1',
#   'COPS6',
#   'COPS5',
#   'COPS8',
#   'COPS4',
#   'COPS7A',
#   'COPS3'],
#  'Ubiquitin E3 ligase (FBXO31, SKP1A, CUL1, RBX1)': ['RBX1',
#   'SKP1',
#   'CUL1',
#   'FBXO31'],
#  'SNARE complex (STX4, SNAP23, VAMP1)': ['SNAP23', 'VAMP1', 'STX4'],
#  'SNARE complex (STX4, SNAP23, VAMP2)': ['SNAP23', 'VAMP2', 'STX4'],
#  'SNARE complex (STX4, VAMP1, VAMP7)': ['VAMP1', 'VAMP7', 'STX4'],
#  'SIN3-ING1b complex I': ['SAP18',
#   'SAP30',
#   'RBBP4',
#   'HDAC1',
#   'RBBP7',
#   'ARID4B',
#   'HDAC2',
#   'SIN3A',
#   'ING1'],
#  'SIN3-ING1b complex II': ['SAP18',
#   'ARID1A',
#   'SAP30',
#   'ACTL6A',
#   'SMARCA4',
#   'RBBP4',
#   'SMARCB1',
#   'HDAC1',
#   'RBBP7',
#   'ARID4B',
#   'SMARCC2',
#   'HDAC2',
#   'SMARCC1',
#   'SMARCD1',
#   'SIN3A',
#   'ING1'],
#  'Exon junction complex (EIF4A3, MLN51, MAGOH, Y14)': ['CASC3',
#   'EIF4A3',
#   'MAGOH',
#   'RBM8A'],
#  'NCOR-HDAC3 complex': ['HDAC3', 'TBL1X', 'NCOR1', 'GPS2', 'TBL1XR1'],
#  'eIF3 complex (EIF3S6, EIF3S5, EIF3S4, EIF3S3, EIF3S6IP, EIF3S2, EIF3S9, EIF3S12,  EIF3S10, EIF3S8,  EIF3S1, EIF3S7)': ['EIF3F',
#   'EIF3D',
#   'EIF3H',
#   'EIF3G',
#   'EIF3J',
#   'EIF3B',
#   'EIF3E',
#   'EIF3I',
#   'EIF3A',
#   'EIF3C',
#   'EIF3K',
#   'EIF3L'],
#  'NCOR-SIN3-RPD3 complex': ['SIN3B', 'HDAC2', 'SIN3A', 'NCOR2'],
#  'C/EBPalpha-HNF6 complex': ['CEBPA', 'ONECUT1'],
#  'NCOR-SIN3-HDAC1 complex': ['HDAC1', 'SIN3A', 'NCOR2'],
#  'TRAF6-TAK1 complex': ['MAP3K7', 'TRAF6'],
#  'MeCP2-SIN3A-HDAC complex': ['MECP2', 'HDAC1', 'HDAC2', 'SIN3A'],
#  'SMRT core complex': ['HDAC3', 'TBL1X', 'NCOR2'],
#  'UTM-SGCE-DAG1-CAV1-NOS3 complex': ['SGCE', 'NOS3', 'UTRN', 'CAV1', 'DAG1'],
#  'Exon junction complex (EIF4A3, MLN51, UPF3B, MAGOH, Y14)': ['CASC3',
#   'EIF4A3',
#   'MAGOH',
#   'UPF3B',
#   'RBM8A'],
#  'Exon junction complex (EIF4A3, MLN51, UPF3B, MAGOH, Y14, PYM)': ['CASC3',
#   'EIF4A3',
#   'MAGOH',
#   'UPF3B',
#   'PYM1',
#   'RBM8A'],
#  'Prune-Gelsolin complex': ['GSN', 'PRUNE'],
#  'Prune-GSK3beta complex': ['GSK3B', 'PRUNE'],
#  'Prune/Nm23-H1 complex': ['NME1', 'PRUNE'],
#  'Apoptosis- and splicing-associated protein complex (ASAP-L), SAP18, RNPS1, Acinus-L': ['SAP18',
#   'RNPS1',
#   'ACIN1'],
#  'Y14-Magoh complex': ['MAGOH', 'RBM8A'],
#  'Dysferlin-affixin complex': ['DYSF', 'PARVB'],
#  'TREX complex': ['THOC5',
#   'DDX39B',
#   'THOC7',
#   'ALYREF',
#   'THOC6',
#   'THOC2',
#   'THOC1',
#   'THOC3'],
#  'NDPKA-AMPKalpha1 complex': ['NME1', 'PRKAA1'],
#  'EIF4A3-MLN51 complex': ['CASC3', 'EIF4A3'],
#  'THO complex': ['THOC5', 'THOC7', 'THOC6', 'THOC2', 'THOC1'],
#  'CBC complex (cap binding complex)': ['NCBP2', 'NCBP1'],
#  'Exon junction complex': ['EIF4A3',
#   'MAGOH',
#   'DDX39B',
#   'RNPS1',
#   'ALYREF',
#   'SRRM1',
#   'UPF3B',
#   'RBM8A'],
#  'LARC complex (LCR-associated remodeling complex)': ['ARID1A',
#   'MTA2',
#   'MBD3',
#   'ACTL6A',
#   'HNRNPC',
#   'SMARCA4',
#   'ACTB',
#   'RBBP4',
#   'SMARCB1',
#   'HDAC1',
#   'CHD4',
#   'SMARCC2',
#   'GATAD2B',
#   'HDAC2',
#   'DPF2',
#   'SMARCC1',
#   'SMARCD2',
#   'SMARCE1',
#   'MBD2'],
#  'URI complex (Unconventional prefoldin RPB5 Interactor)': ['URI1',
#   'POLR2E',
#   'SKP1',
#   'SKP2',
#   'CUL1',
#   'PFDN2',
#   'STAP1',
#   'RUVBL2',
#   'RUVBL1'],
#  'ITCH-USP9X complex': ['USP9X', 'ITCH'],
#  'SMG-1-UPF-ERF1-ERF3 complex (SURF)': ['GSPT1', 'ETF1', 'UPF1', 'SMG1'],
#  'MR-UBC9-SRC1 complex': ['NR3C2', 'PPP3CA', 'NCOA1'],
#  'NuA4/Tip60-HAT complex B': ['ACTL6A',
#   'KAT5',
#   'EPC1',
#   'DMAP1',
#   'MORF4L1',
#   'RUVBL2',
#   'RUVBL1',
#   'TRRAP'],
#  'Exosome': ['EXOSC10',
#   'EXOSC9',
#   'EXOSC2',
#   'EXOSC7',
#   'EXOSC6',
#   'DIS3L',
#   'EXOSC8',
#   'MPHOSPH6',
#   'EXOSC4',
#   'EXOSC5',
#   'EXOSC3',
#   'EXOSC1'],
#  'DDB complex': ['DDB1', 'DDB2'],
#  'SNARE complex (VAMP2, SNAP25, STX1a, CPLX1)': ['CPLX1',
#   'SNAP25',
#   'VAMP2',
#   'STX1A'],
#  'SNARE complex (VAMP2, SNAP25, STX1a, CPLX2)': ['SNAP25',
#   'VAMP2',
#   'STX1A',
#   'CPLX2'],
#  'SNARE complex (STX11, VAMP2, SNAP23)': ['SNAP23', 'STX11', 'VAMP2'],
#  'NuA4/Tip60-HAT complex A': ['YEATS4',
#   'ACTL6A',
#   'EPC2',
#   'KAT5',
#   'EP400',
#   'BRD8',
#   'EPC1',
#   'MEAF6',
#   'DMAP1',
#   'MRGBP',
#   'ING3',
#   'MORF4L1',
#   'RUVBL2',
#   'RUVBL1',
#   'TRRAP'],
#  'DMAP1-associated complex': ['ACTL6A',
#   'VPS72',
#   'SRCAP',
#   'EP400',
#   'BRD8',
#   'EPC1',
#   'DMAP1',
#   'RUVBL2',
#   'RUVBL1',
#   'TRRAP'],
#  'SNARE complex (STX2, SNAP23)': ['SNAP23', 'STX2'],
#  'BRG1-SIN3A-HDAC containing SWI/SNF remodeling complex I': ['ARID1A',
#   'PRMT5',
#   'ACTL6A',
#   'SMARCA4',
#   'SMARCB1',
#   'SMARCC2',
#   'HDAC2',
#   'SMARCC1',
#   'SMARCE1',
#   'SMARCD1',
#   'SIN3A'],
#  'SNARE complex (STX4, SNAP23)': ['SNAP23', 'STX4'],
#  'BRM-SIN3A-HDAC complex': ['ARID1A',
#   'PRMT5',
#   'ACTL6A',
#   'SMARCA2',
#   'SMARCB1',
#   'SMARCC2',
#   'HDAC2',
#   'SMARCC1',
#   'SMARCD2',
#   'SMARCE1',
#   'SMARCD1',
#   'SIN3A'],
#  'BRG1-associated complex': ['ARID1A',
#   'PRMT5',
#   'ACTL6A',
#   'SMARCA4',
#   'SMARCB1',
#   'SMARCC2',
#   'SMARCC1',
#   'SMARCE1',
#   'SMARCD1'],
#  'BRM-associated complex': ['ARID1A',
#   'PRMT5',
#   'ACTL6A',
#   'SMARCA2',
#   'SMARCB1',
#   'SMARCC2',
#   'SMARCC1',
#   'SMARCD2',
#   'SMARCE1',
#   'SMARCD1'],
#  'eRF1-eRF3-GTP-Mg(2+) complex': ['GSPT1', 'ETF1'],
#  'FCP1-associated protein complex': ['PRMT5',
#   'POLR2B',
#   'GTF2F1',
#   'ERH',
#   'STK38',
#   'WDR77',
#   'CTDP1'],
#  'Upf complex (UPF1, UPF2, UPF3a)': ['UPF1', 'UPF3A', 'UPF2'],
#  'Upf complex (UPF1, UPF2, UPF3b)': ['UPF1', 'UPF3B', 'UPF2'],
#  'Postsplicing complex': ['RNPS1',
#   'UPF1',
#   'UPF3B',
#   'UPF3A',
#   'UPF2',
#   'NXF1',
#   'RBM8A'],
#  'MRIP-MBS-RHOA complex': ['PPP1R12A', 'RHOA', 'MPRIP'],
#  'MRIP-RHOA complex': ['RHOA', 'MPRIP'],
#  'MRIP-MBS complex': ['PPP1R12A', 'MPRIP'],
#  '20S methylosome-SmD complex': ['PRMT5', 'CLNS1A', 'SNRPD1', 'SNRPD3'],
#  'SNARE complex (STX6, SNAP23)': ['SNAP23', 'STX6'],
#  'mRNA decay complex (UPF1, UPF2, UPF3B, DCP2, XRN1, XRN2, EXOSC2, EXOSC4, EXOSC10, PARN)': ['PARN',
#   'EXOSC10',
#   'EXOSC2',
#   'DCP2',
#   'XRN1',
#   'UPF1',
#   'UPF3B',
#   'XRN2',
#   'UPF2',
#   'EXOSC4'],
#  'Anti-SMN protein complex': ['GEMIN2',
#   'SNRPB',
#   'GEMIN4',
#   'SMN1',
#   ' SMN2',
#   'DDX20'],
#  'JBP1-pICln complex': ['PRMT5', 'SNRPB', 'CLNS1A'],
#  'PAR-3-VE-cadherin-beta-catenin complex': ['CDH5', 'CTNNB1', 'PARD3'],
#  'TROY-NGR-LINGO1 complex': ['LINGO1', 'RTN4R', 'TNFRSF19'],
#  'TRPC1-STIM1-ORAI1 complex': ['TRPC1', 'ORAI1', 'CTNND2'],
#  'PAR-6-VE-cadherin complex, endothelial': ['CDH5', 'PARD6A'],
#  'PAR-6-PAR-3-VE-cadherin complex, endothelial': ['CDH5', 'PARD3', 'PARD6A'],
#  'Anti-Sm protein complex': ['PRMT5',
#   'GEMIN2',
#   'SNRPB',
#   'CLNS1A',
#   'GEMIN4',
#   'SMN1',
#   ' SMN2',
#   'DDX20'],
#  '6S methyltransferase complex': ['CLNS1A', 'SNRPD1', 'SNRPD3'],
#  '20S methylosome and RG-containing Sm protein complex': ['PRMT5',
#   'SNRPB',
#   'CLNS1A',
#   'SNRPD1',
#   'SNRPD2',
#   'SNRPD3'],
#  '6S methyltransferase and RG-containing Sm proteins complex': ['SNRPB',
#   'CLNS1A',
#   'SNRPE',
#   'SNRPF',
#   'SNRPG',
#   'SNRPD1',
#   'SNRPD2',
#   'SNRPD3'],
#  '20S methyltransferase core complex': ['PRMT5', 'CLNS1A'],
#  'MEP50-PRMT5-ICLN complex': ['PRMT5', 'CLNS1A', 'WDR77'],
#  'LIN9-BMYB complex': ['MYBL2', 'LIN9'],
#  'PCI-PSA-SCG2 complex': ['SERPINA5', 'KLK3', 'SCG2'],
#  'RICH1/AMOT polarity complex, Flag-Rich1 precipitated': ['CAPZB',
#   'CAPZA1',
#   'AMOT',
#   'ARHGAP17',
#   'MPP5',
#   'PATJ',
#   'SH3KBP1',
#   'CD2AP'],
#  'RICH1-PAR3-aPKC polarity complex': ['PRKCI', 'ARHGAP17', 'PARD3'],
#  'RICH1/AMOT polarity complex, Flag-Amot precipitated': ['MPDZ',
#   'AMOT',
#   'MPP7',
#   'ARHGAP17',
#   'AMOTL1',
#   'MPP5',
#   'PATJ',
#   'AMOTL2'],
#  'DNMT1-EHMT2-PCNA complex': ['PCNA', 'DNMT1', 'EHMT2'],
#  'DNMT1-EHMT2 complex': ['DNMT1', 'EHMT2'],
#  'TRAP-SMCC mediator complex': ['MED19',
#   'MED22',
#   'MED1',
#   'MED25',
#   'MED8',
#   'MED18',
#   'MED4',
#   'MED17',
#   'MED29',
#   'MED11'],
#  'BRAF53-BRCA2 complex': ['KDM1A',
#   'BRCA2',
#   'HDAC1',
#   'HDAC2',
#   'PHF21A',
#   'HMG20B',
#   'RCOR1'],
#  'SNARE complex (STX1A, SNAP29)': ['SNAP29', 'STX1A'],
#  'SNARE complex (VAMP3, VAMP4, VAMP8, STX6)': ['STX6',
#   'VAMP4',
#   'VAMP3',
#   'VAMP8'],
#  'SNARE complex (VAMP3, VAMP4, STX16)': ['STX16', 'VAMP4', 'VAMP3'],
#  'SNARE complex (VAMP3, STX6, VTI1A)': ['STX6', 'VAMP3', 'VTI1A'],
#  'SNARE complex (VAMP4, STX6, STX16, VTI1a, VTI1b)': ['STX16',
#   'STX6',
#   'VAMP4',
#   'VTI1A',
#   'VTI1B'],
#  'PKA (RII-alpha and RII-beta)-AKAP5-ADRB1 complex': ['ADRB1',
#   'PRKAR2A',
#   'AKAP5',
#   'PRKAR2B'],
#  'MTA1 complex': ['MBD3', 'RBBP4', 'MTA1', 'RBBP7', 'HDAC1', 'HDAC2'],
#  'MTA2 complex': ['MTA2',
#   'MBD3',
#   'RBBP4',
#   'HDAC1',
#   'CHD4',
#   'RBBP7',
#   'HDAC2',
#   'SIN3A'],
#  'MTA1-HDAC core complex': ['RBBP4', 'MTA1', 'RBBP7', 'HDAC1', 'HDAC2'],
#  'hMediator complex (MED23, CDK8, CCNC, MED7)': ['MED7',
#   'CCNC',
#   'CDK8',
#   'MED23'],
#  'hMediator complex (MED23, CDK8, CCNC)': ['CCNC', 'CDK8', 'MED23'],
#  'CDK8-CyclinC-Mediator complex': ['CCNC', 'CDK8'],
#  'Mediator complex 1': ['MED14', 'MED6', 'CCNC', 'CDK8', 'MED23'],
#  'Mediator complex 2': ['MED14', 'MED6', 'MED23'],
#  'RET-Rai complex': ['RET', 'SHC3'],
#  'SHC3-GAB1 complex': ['GAB1', 'SHC3'],
#  'KIF3A/B-PAR-3-aPKC-PAR-6 complex': ['KIF3B',
#   'PRKCI',
#   'PARD3',
#   'PARD6A',
#   'KIF3A'],
#  'ARC92-Mediator complex': ['MED7',
#   'MED14',
#   'MED6',
#   'MED26',
#   'CDK8',
#   'MED1',
#   'MED25',
#   'MED12',
#   'MED15',
#   'MED17',
#   'MED13',
#   'MED23',
#   'MED16'],
#  'CRSP-Mediator 2 complex': ['MED7',
#   'MED14',
#   'MED24',
#   'MED6',
#   'MED15',
#   'MED18',
#   'MED4',
#   'MED17',
#   'MED23',
#   'MED16'],
#  'FGFR1-KAL11 complex': ['FGFR1', 'ANOS1'],
#  'SNARE complex (SNAP23, STX1A)': ['SNAP23', 'STX1A'],
#  'CERF complex (CECR2-containing remodeling factor complex)': ['SMARCA1',
#   'CECR2'],
#  'PAR3-PAR6-PALS1 complex': ['MPP5', 'PARD3', 'PARD6A'],
#  'Remodeling and spacing factor (RSF) complex': ['SMARCA5', 'RSF1'],
#  'SNF2L-RSF1 complex': ['SMARCA1', 'RSF1'],
#  'Toposome': ['HNRNPC', 'TOP2A', 'DHX9', 'SSRP1', 'PRPF8', 'SRPK1', 'DDX21'],
#  'SCRIB-LGL2 complex': ['SCRIB', 'LLGL2'],
#  'CENP-A NAC complex': ['CENPC', 'CENPU', 'CENPT', 'CENPN', 'CENPH', 'CENPM'],
#  'SCRIB-VANGL2 complex': ['SCRIB', 'VANGL2'],
#  'CEN complex': ['SMARCA5',
#   'CENPB',
#   'HSPA5',
#   'HSPA8',
#   'FBL',
#   'BMI1',
#   'CENPA',
#   'KIF23',
#   'CENPC',
#   'RING1',
#   'SSRP1',
#   'CBX3',
#   'CUL4A',
#   'WTAP',
#   'DDB1',
#   'COBLL1',
#   'ZC3H13',
#   'KIAA1429',
#   'PLPPR3',
#   'CENPU',
#   'CENPL',
#   'NUP93',
#   'SHCBP1',
#   'DHX38',
#   'CENPI',
#   'ZFP91',
#   'RSF1',
#   'RNF2',
#   'CENPK',
#   'CENPO',
#   'SRRT',
#   'WDR11',
#   'RACGAP1',
#   'CENPH',
#   'CBX8',
#   'CENPM',
#   'SUPT16H'],
#  'SCRIB-GIT1-ARHGEF7 complex': ['ARHGEF7', 'SCRIB', 'GIT1'],
#  'SCRIB-APC complex': ['APC', 'SCRIB'],
#  'FACT-NEK9 complex': ['SSRP1', 'NEK9', 'SUPT16H'],
#  'FACT complex': ['SSRP1', 'SUPT16H'],
#  'FACT complex, UV-activated': ['CSNK2A2',
#   'CSNK2B',
#   'CSNK2A1',
#   'SSRP1',
#   'SUPT16H'],
#  'Class C Vps complex (VPS11, VPS18, STX7)': ['STX7', 'VPS11', 'VPS18'],
#  'Class C Vps complex (VPS11, VPS18, VPS16)': ['VPS16', 'VPS11', 'VPS18'],
#  'CDC7-DBF7 complex': ['CDC7', 'DBF4'],
#  'LLGL2-PAR-6B-PRKCI complex': ['PRKCI', 'LLGL2', 'PARD6B'],
#  'PAR-3-PAR-6B-PRKCI complex': ['PRKCI', 'PARD3', 'PARD6B'],
#  'LLGL1-PAR-6B-PRKCI complex': ['PRKCI', 'LLGL1', 'PARD6B'],
#  'EED-EZH2 complex': ['EED', 'RBBP4', 'SUZ12', 'EZH2', 'AEBP2'],
#  'GAA1-GPI8-PIGT-PIG-PIGS complex': ['GPAA1', 'PIGK', 'PIGT', 'PIGS', 'PIGU'],
#  'KIN17-PCNA-RPA70 complex': ['KIN', 'PCNA', 'RPA1'],
#  'p23 protein complex': ['HNRNPA2B1', 'PTGES3', 'PDCD6'],
#  'TorsinA-TorsinB complex': ['TOR1A', 'TOR1B'],
#  'RC complex (Replication competent complex)': ['POLA1',
#   'CCNA2',
#   'CDK2',
#   'RFC4',
#   'RFC2',
#   'RFC1',
#   'RFC5',
#   'RFC3',
#   'POLA2'],
#  'RC complex during S-phase of cell cycle': ['PARP1',
#   'POLA1',
#   'TOP1',
#   'RPA2',
#   'LIG1',
#   'CCNA2',
#   'CDK2',
#   'RPA1',
#   'POLD1',
#   'RPA3',
#   'RFC2',
#   'RFC1',
#   'POLE'],
#  'RC complex during G2/M-phase of cell cycle': ['CDK1',
#   'PARP1',
#   'POLA1',
#   'TOP1',
#   'CCNB1',
#   'RPA2',
#   'CCNA2',
#   'RPA1',
#   'POLD1',
#   'RPA3',
#   'RFC2',
#   'RFC1',
#   'POLE'],
#  'CAK core complex (Cdk-activating kinase core complex)': ['CDK7', 'CCNH'],
#  'CAK complex (Cdk-activating kinase complex)': ['CDK7', 'CCNH', 'MNAT1'],
#  'HNF4A-SUB1 complex': ['HNF4A', 'SUB1'],
#  'CAK-ERCC2 complex': ['ERCC2', 'CDK7', 'CCNH', 'MNAT1'],
#  'ORC 2-4 complex (origin recognition 2-4 complex)': ['ORC4', 'ORC2', 'ORC3'],
#  'ORC 2-5 complex (origin recognition 2-5 complex)': ['ORC5',
#   'ORC4',
#   'ORC2',
#   'ORC3'],
#  'TFIIH transcription factor core complex': ['ERCC3',
#   'GTF2H1',
#   'GTF2H2',
#   'GTF2H3',
#   'GTF2H4'],
#  'ORC 1-5 complex (origin recognition 1-5 complex)': ['ORC5',
#   'ORC4',
#   'ORC1',
#   'ORC2',
#   'ORC3'],
#  'PCNA-PAF complex': ['PCNA', 'KIAA0101'],
#  'p33ING1b-PCNA complex': ['KIAA0101', 'ING1'],
#  'Alpha-dystrobrevin-ZO-1-actin complex': ['ACTB', 'TJP1', 'DTNA'],
#  'SRA-SRC-1 ribonucleoprotein complex': ['NCOA1', 'SRA1'],
#  'Snurportin-CRM1-RanGTP complex': ['XPO1', 'SNUPN', 'RAN'],
#  'Ubiquitin E3 ligase (FBXW11, SKP1A, CUL1, RBX1)': ['RBX1',
#   'SKP1',
#   'CUL1',
#   'FBXW11'],
#  'ESR1-RELA-BCL3-NCOA3 complex': ['ESR1', 'BCL3', 'RELA', 'NCOA3'],
#  'ZNF198-PML complex': ['PML', 'ZMYM2'],
#  'ZNF198-SUMO1 complex': ['SUMO1', 'ZMYM2'],
#  'DIPA-MCRS1 complex': ['CCDC85B', 'MCRS1'],
#  'SNX complex (SNX1, SNX6)': ['SNX1', 'SNX6'],
#  'Retromer complex (SNX1, SNX2, VPS35, VPS29, VPS26B)': ['SNX2',
#   'SNX1',
#   'VPS26B',
#   'VPS35',
#   'VPS29'],
#  'BAR-BCL2-CASP8 complex': ['BCL2', 'CASP8', 'BFAR'],
#  'GRASP-GRP1 complex': ['CYTH3', 'GRASP'],
#  'IFP35-NMI complex': ['IFI35', 'NMI'],
#  'CD8A-LCK complex': ['CD8A', 'LCK'],
#  '12S U11 snRNP': ['SNRPB',
#   'SNRPE',
#   'SNRPF',
#   'SNRPG',
#   'SNRPD1',
# ...
#  'PRNP homo-oligomer complex': ['PRNP'],
#  'AXL homodimer complex': ['AXL'],
#  'STAT5B homodimer complex': ['STAT5B'],
#  'IL12A homodimer complex': ['IL12A'],
#  'IL12A-IL12B complex': ['IL12A', 'IL12B'],
#  'IL12A-IL12B-IL12RB1 complex': ['IL12A', 'IL12B', 'IL12RB1'],
#  'IL12B-IL12RB1-IL12RB2 complex': ['IL12B', 'IL12RB1', 'IL12RB2'],
#  'IL12A-IL12B-IL12RB2 complex': ['IL12A', 'IL12B', 'IL12RB2'],
#  'STAT5A homodimer complex': ['STAT5A'],
#  'IL12RB1-IL12RB2 complex': ['IL12RB1', 'IL12RB2'],
#  'JAK2-IL12RB2 complex': ['JAK2', 'IL12RB2'],
#  'BNIP2-ARHGAP8 complex': ['ARHGAP8', 'BNIP2'],
#  'MALT1 homo-oligomer complex': ['MALT1'],
#  'BCL10 homo-oligomer complex': ['BCL10'],
#  'BCL10-MALT1 complex': ['BCL10', 'MALT1'],
#  'CASP8-FADD-MALT1-BCL10 complex': ['BCL10', 'FADD', 'CASP8', 'MALT1'],
#  'CASP8-CHUK-IKBKB-MALT1-BCL10 complex': ['IKBKB',
#   'CHUK',
#   'BCL10',
#   'CASP8',
#   'MALT1'],
#  'TNFRSF11A-TRAF6-SRC complex': ['SRC', 'TRAF6', 'TNFRSF11A'],
#  'TRAF6 homo-oligomer complex': ['TRAF6'],
#  'B-raf-MAP3K11 complex': ['MAP3K11', 'B-raf'],
#  'NFKB1-NFKB2-REL-RELA-RELB complex': ['NFKB1',
#   'NFKB2',
#   'RELB',
#   'RELA',
#   'REL'],
#  'NFKB1-NFKB2-RELA-RELB complex': ['NFKB1', 'NFKB2', 'RELB', 'RELA'],
#  'CHUK-IKBKB-MAP3K14 complex': ['IKBKB', 'CHUK', 'MAP3K14'],
#  'IKKA-IKKB complex': ['IKBKB', 'CHUK'],
#  'IKKB-NIK complex': ['IKBKB', 'MAP3K14'],
#  'IkappaB kinase complex (IKBKB, CHUK, IKBKAP, NFKBIA, RELA, MAP3K14)': ['IKBKB',
#   'CHUK',
#   'IKBKAP',
#   'NFKBIA',
#   'RELA',
#   'MAP3K14'],
#  'CDC37-HSP90AA1-HSP90AB1-MAP3K11 complex': ['HSP90AA1',
#   'HSP90AB1',
#   'CDC37',
#   'MAP3K11'],
#  'CHUK-ERC1-IKBKB-IKBKG': ['IKBKB', 'CHUK', 'ERC1', 'IKBKG'],
#  'I-kappa-B kinase complex': ['IKBKB', 'CHUK', 'IKBKG'],
#  'IKBKG homodimer complex': ['IKBKG'],
#  'IKK-alpha--ER-alpha-AIB1 complex': ['CHUK', 'ESR1', 'NCOA3'],
#  'DNAJB2-HSPA8-PSMA3 complex': ['HSPA8', 'DNAJB2', 'PSMA3'],
#  'MAP2K5-PRKCI-SQSTM1 complex': ['PRKCI', 'MAP2K5', 'SQSTM1'],
#  'HSF1-YWHAE complex': ['YWHAE', 'HSF1'],
#  'ARNT-HLF complex': ['ARNT', 'HLF'],
#  'ITGAM-ITGB2-CD11 complex': ['ITGB2', 'CD63', 'ITGAM'],
#  'YBX1-AKT1 complex': ['AKT1', 'YBX1'],
#  'AR-AKT-APPL complex': ['AR', 'AKT1', 'APPL1'],
#  'AOF2-AR complex': ['KDM1A', 'AR'],
#  'APPBP1-UBA3 complex': ['NAE1', 'UBA3'],
#  'Ubiquitin E3 ligase (CDC34, CUL1, RBX1)': ['CDC34', 'RBX1', 'CUL1'],
#  'Ubiquitin E3 ligase (CHEK1, CUL4A)': ['CHEK1', 'CUL4A'],
#  'Ubiquitin E3 ligase (CDT1, DDB1, CUL4A, RBX1)': ['RBX1',
#   'CUL4A',
#   'DDB1',
#   'CDT1'],
#  'COP9 signalosome complex': ['COPS2',
#   'GPS1',
#   'COPS6',
#   'COPS5',
#   'COPS8',
#   'COPS4',
#   'COPS7A',
#   'COPS3'],
#  'CNS-P53 complex': ['TP53',
#   'COPS2',
#   'GPS1',
#   'COPS6',
#   'COPS5',
#   'COPS8',
#   'COPS4',
#   'COPS7A',
#   'COPS3'],
#  'Kaiso-NCOR complex': ['HDAC3',
#   'TBL1X',
#   'KDM4A',
#   'NCOR1',
#   'KIF11',
#   'GPS2',
#   'ZBTB33',
#   'CORO2A',
#   'TBL1XR1',
#   'TRIM33'],
#  'Ubiquitin E3 ligase (CDC34, NEDD8, BTRC, CUL1, SKP1A, RBX1)': ['RBX1',
#   'SKP1',
#   'CUL1',
#   'NEDD8',
#   'BTRC'],
#  'Ubiquitin E3 ligase (SMAD3, BTRC, CUL1, SKP1A, RBX1)': ['RBX1',
#   'SKP1',
#   'SMAD3',
#   'CUL1',
#   'BTRC'],
#  'Ubiquitin E3 ligase (FBXO18, SKP1A, CUL1, RBX1)': ['RBX1',
#   'SKP1',
#   'CUL1',
#   'FBXO18'],
#  'Ubiquitin E3 ligase (NIPA, SKP1A, CUL1, RBX1)': ['RBX1',
#   'SKP1',
#   'CUL1',
#   'ZC3HC1'],
#  '9-1-1-LIG1 complex': ['RAD1', 'HUS1', 'LIG1', 'RAD9A'],
#  '9-1-1-FEN1 complex': ['RAD1', 'HUS1', 'FEN1', 'RAD9A'],
#  '9-1-1-POLB complex': ['RAD1', 'HUS1', 'POLB', 'RAD9A'],
#  'CHTF18-RFC2-5 complex': ['RFC4', 'RFC2', 'RFC5', 'RFC3', 'CHTF18'],
#  'RFC2-5 subcomplex': ['RFC4', 'RFC2', 'RFC5', 'RFC3'],
#  'PCNA-RFC2-5 complex': ['PCNA', 'RFC4', 'RFC2', 'RFC5', 'RFC3'],
#  'BRD4-RFC complex': ['BRD4', 'RFC4', 'RFC2', 'RFC1', 'RFC5', 'RFC3'],
#  'MCM8-ORC2-CDC6 complex': ['ORC2', 'CDC6', 'MCM8'],
#  'ORC5-ORC1 complex': ['ORC5', 'ORC1'],
#  'BRCA1-IRIS-pre-replication complex': ['GMNN', 'ORC1', 'BRCA1', 'CDC6'],
#  'BARD1-BRCA1-CSTF complex': ['CSTF2', 'BRCA1', 'CSTF1', 'CSTF3', 'BARD1'],
#  'BRCA1-BARD1-POLR2A complex': ['POLR2A', 'BRCA1', 'BARD1'],
#  'LMO4-BRCA1-CTIP-LDB1 complex': ['BRCA1', 'LMO4', 'LDB1', 'RBBP8'],
#  'BRCA1-LMO4-CTIP complex': ['BRCA1', 'LMO4', 'RBBP8'],
#  'MDC1-MRN-ATM-FANCD2 complex': ['NBN',
#   'MRE11A',
#   'ATM',
#   'MDC1',
#   'RAD50',
#   'FANCD2'],
#  'MDC1-MRE11-RAD50-NBS1 complex': ['NBN', 'MRE11A', 'MDC1', 'RAD50'],
#  'TERF1 homodimer complex': ['TERF1'],
#  'RAD52-ERCC4-ERCC1 complex': ['ERCC1', 'RAD52', 'ERCC4'],
#  'BLM complex II': ['RPA2', 'RPA1', 'RPA3', 'BLM', 'TOP3A', 'RMI1'],
#  'BLM-TOP3A complex': ['BLM', 'TOP3A'],
#  'MSH2/6-BLM-p53-RAD51 complex': ['TP53', 'MSH2', 'MSH6', 'BLM', 'RAD51'],
#  'MutS-alpha-PK-zeta complex': ['MSH2', 'MSH6', 'PRKCZ'],
#  'BLM-RAD51L3-XRCC2 complex': ['XRCC2', 'RAD51D', 'BLM'],
#  'PCNA homotrimer complex': ['PCNA'],
#  'Replication-coupled CAF-1-MBD1-ETDB1 complex': ['CHAF1A', 'SETDB1', 'MBD1'],
#  'ASF1-interacting protein complex': ['HIRA',
#   'HIST1H3A',
#   '',
#   'CHAF1A',
#   'CHAF1B',
#   'ASF1B',
#   'ASF1A'],
#  'ASF1-histone containing complex': ['CHEK2',
#   'NASP',
#   'ST13',
#   'HIST1H3A',
#   '',
#   'CHAF1B',
#   'ASF1B',
#   'ASF1A'],
#  'SP1-MCAF2 complex': ['SP1', 'ATF7IP2'],
#  'MBD1-MCAF1-SETDB1 complex': ['SETDB1', 'ATF7IP', 'MBD1'],
#  'HD-RAB8A-OPTN complex': ['HTT', 'RAB8A', 'OPTN'],
#  'TGM2-HD-CALM1 complex': ['TGM2', 'HTT', 'CALM1', ' CAL'],
#  'TGM2-HD complex': ['TGM2', 'HTT'],
#  'CTGF/Hcs24-actin(beta/gamma) complex': ['CTGF', 'ACTB', 'ACTG1'],
#  'Cofilin-actin-CAP1 complex': ['CFL1', 'ACTB', 'CAP1'],
#  'RIAM-Rap1-GTP complex': ['RAP1A', 'APBB1IP'],
#  'VILIP-1-AChR-alpha-4-AChR-beta-2 complex': ['CHRNB2', 'CHRNA4', 'VSNL1'],
#  'PPP3CA-PPP3CA-RCAN1 complex': ['PPP3CB', 'RCAN1', 'PPP3CA'],
#  'PICK1-GRIP1-GLUR2 complex': ['GRIA2', 'PICK1', 'GRIP1'],
#  'ABI1-WASF2 complex': ['ABI1', 'WASF2'],
#  'ABI1-WASL complex': ['WASL', 'ABI1'],
#  'Profilin 2 complex': ['ROCK2',
#   'HSPA8',
#   'SYN1',
#   'PFN2',
#   'ACTB',
#   'DNM1',
#   'CYFIP1',
#   'SYN2',
#   'NCKAP1'],
#  'AP3D1-AP3S2 complex': ['AP3D1', 'AP3S2'],
#  'AP3D1-AP3S1 complex': ['AP3D1', 'AP3S1'],
#  'ITGA6-ITGB4-Laminin10/12 complex': ['LAMA5',
#   'LAMC1',
#   'ITGB4',
#   'ITGA6',
#   'LAMB2'],
#  'ITGA6-ITGB4-CD151 complex': ['ITGB4', 'ITGA6', 'CD151'],
#  'ITGA6-ITGB4-FYN complex': ['FYN', 'ITGB4', 'ITGA6'],
#  'ITGA6-ITGB4-LAMA5 complex': ['LAMA5', 'ITGB4', 'ITGA6'],
#  'ITGA6-ITGB4 complex': ['ITGB4', 'ITGA6'],
#  'ITGAV-ITGB8-MMP14-TGFB1 complex': ['TGFB1', 'ITGAV', 'ITGB8', 'MMP14'],
#  'ITGAV-ITGB5-PLAUR complex': ['ITGAV', 'ITGB5', 'PLAUR'],
#  'ITGAV-ITGB5-ICAM4 complex': ['ITGAV', 'ITGB5', 'ICAM4'],
#  'ITGAV-ITGB5-ADAM9 complex': ['ITGAV', 'ITGB5', 'ADAM9'],
#  'ITGAV-ITGB5-SPP1 complex': ['ITGAV', 'SPP1', 'ITGB5'],
#  'ITGAV-ITGB5-CYR61 complex': ['CYR61', 'ITGAV', 'ITGB5'],
#  'ITGAV-ITGB5 complex': ['ITGAV', 'ITGB5'],
#  'ITGB6-FYN-FN1 complex': ['FN1', 'FYN', 'ITGB6'],
#  'ITGAV-ITGB6-SPP1 complex': ['ITGAV', 'SPP1', 'ITGB6'],
#  'ITGAV-ITGB6-TGFB3 complex': ['ITGAV', 'TGFB3', 'ITGB6'],
#  'ITGAV-ITGB6 complex': ['ITGAV', 'ITGB6'],
#  'ITGAV-ITGB3-CD47-FCER2 complex': ['ITGB3', 'FCER2', 'ITGAV', 'CD47'],
#  'ITGB3-ITGAV-CD47 complex': ['ITGB3', 'ITGAV', 'CD47'],
#  'ITGAV-ITGB3-SPP1 complex': ['ITGB3', 'ITGAV', 'SPP1'],
#  'ITGAV-ITGB3-ADAM15 complex': ['ITGB3', 'ITGAV', 'ADAM15'],
#  'ITAGV-ITGB3-F11R complex': ['ITGB3', 'ITGAV', 'F11R'],
#  'ITGAV-ITGB3-PXN-PTK2b complex': ['ITGB3', 'ITGAV', 'PXN', 'PTK2B'],
#  'ITGAV-ITGB3-ADAM23 complex': ['ADAM23', 'ITGB3', 'ITGAV'],
#  'ITGAV-ITGB3-COL4A3 complex': ['ITGB3', 'ITGAV', 'COL4A3'],
#  'ITGAV-ITGB3-PPAP2b complex': ['PLPP3', 'ITGB3', 'ITGAV'],
#  'ITGAV-ITGB3-EGFR complex': ['EGFR', 'ITGB3', 'ITGAV'],
#  'ITGA2B-ITGB3-CD9 complex': ['ITGB3', 'ITGA2B', 'CD9'],
#  'ITGAV-ITGB3-LAMA4 complex': ['ITGB3', 'ITGAV', 'LAMA4'],
#  'FN1-TGM2 complex': ['FN1', 'TGM2'],
#  'ITGA2B-ITGB3-FN1-TGM2 complex': ['FN1', 'ITGB3', 'ITGA2B', 'TGM2'],
#  'ITGA2b-ITGB3-CD47-SRC complex': ['ITGB3', 'ITGA2B', 'SRC', 'CD47'],
#  'ITGA2b-ITGB3-TLN1 complex': ['ITGB3', 'ITGA2B', 'TLN1'],
#  'ITGA2B-ITGB3-CIB1 complex': ['ITGB3', 'ITGA2B', 'CIB1'],
#  'ITGA2B-ITGB3 complex': ['ITGB3', 'ITGA2B'],
#  'ITGA2B-ITGB3-F11R complex': ['ITGB3', 'ITGA2B', 'F11R'],
#  'ITGA5-ITGB1-FN1-TGM2 complex': ['FN1', 'ITGB1', 'ITGA5', 'TGM2'],
#  'ITGA5-ITGB1-ADAM15 complex': ['ITGB1', 'ITGA5', 'ADAM15'],
#  'ITGA5-ITGB4 complex': ['ITGB1', 'ITGA5'],
#  'CD98-LAT2-ITGB1 complex': ['ITGB1', 'SLC3A2', 'SLC7A8'],
#  'ITGA7-ITGB1-CD151 complex': ['ITGB1', 'CD151', 'ITGA7'],
#  'ITGA7-ITGB1-CD9 complex': ['ITGB1', 'CD9', 'ITGA7'],
#  'ITGA7-ITGB1-ITGB1BP3 complex': ['ITGB1', 'ITGA7', 'NMRK2'],
#  'ITGA3-ITGB1-BSG complex': ['ITGB1', 'ITGA3', 'BSG'],
#  'ITGA3-ITGB1-CD63 complex': ['ITGB1', 'CD63', 'ITGA3'],
#  'ITGA3-ITGB1-CD151 complex': ['ITGB1', 'ITGA3', 'CD151'],
#  'ITGA3-ITGB1-THBS1 complex': ['ITGB1', 'THBS1', 'ITGA3'],
#  'ITGA3-ITGB1 complex': ['ITGB1', 'ITGA3'],
#  'ITGA6-ITGB1-CD151 complex': ['ITGB1', 'ITGA6', 'CD151'],
#  'ITGA6-ITGB1 complex': ['ITGB1', 'ITGA6'],
#  'ITGB1-RAP1A-PKD1 complex': ['ITGB1', 'RAP1A', 'PKD1'],
#  'ITGA4-ITGB1-EMILIN1 complex': ['ITGB1', 'ITGA4', 'EMILIN1'],
#  'ITGA4-ITGB1 complex': ['ITGB1', 'ITGA4'],
#  'ITGA4-ITGB1-CD81 complex': ['ITGB1', 'ITGA4', 'CD81'],
#  'ITGA4-ITGB1-CD53 complex': ['ITGB1', 'ITGA4', 'CD53'],
#  'ITGA4-ITGB1-VCAM1 complex': ['ITGB1', 'ITGA4', 'VCAM1'],
#  'ITGA4-ITGB1-JAM2 complex': ['ITGB1', 'ITGA4', 'JAM2'],
#  'ITGA4-ITGB1-CD47 complex': ['ITGB1', 'ITGA4', 'CD47'],
#  'ITGA4-ITGB1-CD63 complex': ['ITGB1', 'CD63', 'ITGA4'],
#  'ITGA4-ITGB1-THBS1 complex': ['ITGB1', 'THBS1', 'ITGA4'],
#  'ITGA4-ITGB1-THBS2 complex': ['ITGB1', 'ITGA4', 'THBS2'],
#  'ITGA2-ITGB1-CD47 complex': ['ITGB1', 'ITGA2', 'CD47'],
#  'ITGA2-ITGB1-CHAD complex': ['CHAD', 'ITGB1', 'ITGA2'],
#  'ITGA2-ITGB1-COL6A3 complex': ['ITGB1', 'COL6A3', 'ITGA2'],
#  'ITGA2-ITGB1 complex': ['ITGB1', 'ITGA2'],
#  'ITGA1-ITGB1-COL6A3 complex': ['ITGB1', 'COL6A3', 'ITGA1'],
#  'ITGA1-ITGB1-PTPN2 complex': ['ITGB1', 'PTPN2', 'ITGA1'],
#  'ITGAV-ITGB1 complex': ['ITGB1', 'ITGAV'],
#  'ITGA6-ITGB1-CYR61 complex': ['CYR61', 'ITGB1', 'ITGA6'],
#  'ITGA8-ITGB1 complex': ['ITGB1', 'ITGA8'],
#  'ITGA9-ITGB1-ADAM9 complex': ['ITGB1', 'ADAM9', 'ITGA9'],
#  'ITGA9-ITGB1-VCAM1 complex': ['ITGB1', 'VCAM1', 'ITGA9'],
#  'ITGA9-ITGB1-TNC complex': ['ITGB1', 'TNC', 'ITGA9'],
#  'ITGB1-ITGA9 complex': ['ITGB1', 'ITGA9'],
#  'ITGA9-ITGB1-ADAM15 complex': ['ITGB1', 'ADAM15', 'ITGA9'],
#  'ITGA9-ITGB1-FIGF complex': ['VEGFD', 'ITGB1', 'ITGA9'],
#  'ITGA9-ITGB1-ADAM12 complex': ['ADAM12', 'ITGB1', 'ITGA9'],
#  'Multiprotein complex (monoubiquitination)': ['EGFR',
#   'CBLB',
#   'UBB',
#   'SH3KBP1'],
#  'CIN85-CBL-SH3GL2-EGFR complex, EGF stimulated': ['EGFR',
#   'CBL',
#   'SH3GL2',
#   'SH3KBP1'],
#  'CIN85-SH3GL2 complex': ['SH3KBP1', 'SH3GL2'],
#  'MET-CIN85-SH3GL3-CBL complex, HGF stimulated': ['MET',
#   'CBL',
#   'SH3KBP1',
#   'SH3GL3'],
#  'CIN85-SH3GL3 complex': ['SH3KBP1', 'SH3GL3'],
#  'Caveolin-1 homodimer complex': ['CAV1'],
#  'p130Cas-ER-alpha-cSrc-kinase- PI3-kinase p85-subunit complex': ['ESR1',
#   'SRC',
#   'PIK3R1',
#   'BCAR1'],
#  'SRC-PRKCD-CDCP1 complex': ['SRC', 'PRKCD', 'CDCP1'],
#  'CRKL-PDGFRA-CRK-RAPGEF1 complex': ['PDGFRA', 'CRK', 'CRKL', 'RAPGEF1'],
#  'CIN85 complex (CIN85, CRK, BCAR1, CBL, PIK3R1, GRB2, SOS1)': ['CBL',
#   'PIK3R1',
#   'CRK',
#   'BCAR1',
#   'GRB2',
#   'SOS1',
#   'SH3KBP1'],
#  'GIPC1-LHCGR complex': ['GIPC1', 'LHCGR'],
#  'GIPC1-NTRK1-RGS19 complex': ['GIPC1', 'NTRK1', 'RGS19'],
#  'NCR3-CD247 complex': ['NCR3', 'CD247'],
#  'ZAP70-CRKL-WIPF1-WAS complex': ['WIPF1', 'WAS', 'ZAP70', 'CRKL'],
#  'CRKL-WIPF1-WAS complex': ['WIPF1', 'WAS', 'CRKL'],
#  'N-WASp homomer complex': ['WASL'],
#  'ERBB2-MEMO-SHC complex': ['ERBB2', 'SHC1', 'MEMO1'],
#  'LAT-PLC-gamma-1-p85-GRB2-CBL-VAV-SLP-76 signaling complex, C305 activated': ['LAT',
#   'VAV1',
#   'PLCG1',
#   'CBL',
#   'PIK3R1',
#   'GRB2',
#   'LCP2'],
#  'Cbl-SLP-76-Grb2 complex, Fc receptor gamma-R1 stimulated': ['CBL',
#   'GRB2',
#   'LCP2'],
#  'SLP-76-Cbl-Grb2-Shc complex, Fc receptor gamma-R1 stimulated': ['CBL',
#   'SHC1',
#   'GRB2',
#   'LCP2'],
#  'PLC-gamma-2-SLP-76-Lyn-Grb2 complex': ['LYN', 'PLCG2', 'GRB2', 'LCP2'],
#  'PKC-alpha-PLD1-PLC-gamma-2 signaling complex, lacritin stimulated': ['PLCG2',
#   'PRKCA',
#   'PLD1'],
#  'BCR-ABL (p210 fusion protein)-GRB2 complex': ['BCR/ABL fu', 'GRB2'],
#  'HGF-Met complex': ['MET', 'HGF'],
#  'EGFR-CBL-GRB2 complex': ['EGFR', 'CBL', 'GRB2'],
#  'PLC-gamma-1-SLP-76-SOS1-LAT complex': ['LAT', 'PLCG1', 'SOS1', 'LCP2'],
#  'PDGFRA-PLC-gamma-1-PI3K-SHP-2 complex, PDGF stimulated': ['PDGFRA',
#   'PLCG1',
#   'PIK3R1',
#   'PTPN11'],
#  'p56(LCK)-CAML complex': ['LCK', 'CAMLG'],
#  'FGFR2-c-Cbl-Lyn-Fyn complex': ['FYN', 'LYN', 'FGFR2', 'CBL'],
#  'p21(ras)GAP-Fyn-Lyn-Yes complex, thrombin stimulated': ['FYN',
#   'YES1',
#   'LYN',
#   'RASA1'],
#  'CD20-LCK-LYN-FYN-p75/80 complex, (Raji human B cell line)': ['LCK',
#   'FYN',
#   'LYN',
#   'MS4A1'],
#  'RAB5-EEA1 complex': ['RAB5A', 'EEA1'],
#  'Class C VPS/HOPS complex': ['RAB5A',
#   'EEA1',
#   'VPS39',
#   'VPS16',
#   'VPS11',
#   'VPS18'],
#  'CD19-VAV1-PIK3R1 complex': ['CD19', 'VAV1', 'PIK3R1'],
#  'Sam68-p85 P13K-IRS-1-IR signaling complex': ['INSR',
#   'PIK3R1',
#   'IRS1',
#   'KHDRBS1'],
#  'Sam68-p120GAP complex': ['RASA1', 'KHDRBS1'],
#  'Chromosomal passenger complex CPC (INCENP, BIRC5, AURKB)': ['BIRC5',
#   'AURKB',
#   'INCENP'],
#  'Survivin homodimer complex': ['BIRC5'],
#  'RasGAP-AURKA-survivin complex': ['AURKA', 'BIRC5', 'RASA1'],
#  'Chromosomal passenger complex CPC (CDCA8, AURKB, BIRC5)': ['BIRC5',
#   'CDCA8',
#   'AURKB'],
#  'PGC-1-SRp40-SRp55-SRp75 complex': ['SRSF4', 'SRSF5', 'SRSF6', 'PPARGC1A'],
#  'FOXO1-FHL2-SIRT1 complex': ['FOXO1', 'FHL2', 'SIRT1'],
#  'SIRT1 homotrimer complex': ['SIRT1'],
#  'FOXO3-SIRT1 complex, oxidative stress stimulated': ['FOXO3', 'SIRT1'],
#  'POLR2A-CCNT1-CDK9-NCL-LEM6-CPSF2 complex': ['CCNT1',
#   'NCL',
#   'POLR2A',
#   'CDK9',
#   'CPSF2',
#   'PPARGC1A'],
#  'BRD4 complex': ['MED14',
#   'CCNT1',
#   'BRD4',
#   'MED24',
#   'CDK9',
#   'MED1',
#   'MED12',
#   'MED17'],
#  'P-TEFb-BRD4-TRAP220 complex': ['CCNT1', 'BRD4', 'CDK9', 'MED1'],
#  'P-TEFb-7SKRNA-HEXIM1 complex': ['CCNT1', 'HEXIM1', 'CDK9'],
#  'Transcription elongation factor complex (SUPT5H, CDK9, CCNT1)': ['SUPT5H',
#   'CCNT1',
#   'CDK9'],
#  'P-TEFb-SKP2 complex': ['CCNT1', 'CDK9', 'SKP2'],
#  'CCNT1- CDK9-GRN complex': ['CCNT1', 'GRN', 'CDK9'],
#  'CDK8-MED6-PARP1 complex': ['MED6', 'PARP1', 'CDK8'],
#  'CCNC-CDK8-MED1-MED6-MED7 xcomplex': ['MED7', 'MED6', 'CCNC', 'CDK8', 'MED1'],
#  'CCNC-CDK3 complex': ['CCNC', 'CDK3'],
#  'BETA2-Cyclin D1 complex': ['CCND1', 'NEUROD1'],
#  'HES1 promoter corepressor complex': ['POLR2A',
#   'CDK7',
#   'RBPJ',
#   'EP300',
#   'SUPT6H',
#   'CREBBP'],
#  'HES1 promoter-Notch enhancer complex': ['CCNT1',
#   'POLR2A',
#   'NOTCH1',
#   'CDK8',
#   'CDK7',
#   'CDK9',
#   'RBPJ',
#   'EP300',
#   'MED1',
#   'SUPT6H',
#   'MAML1',
#   'INPP5K',
#   'SUPT16H'],
#  'CREBBP-KAT2B-MYOD1 complex': ['MYOD1', 'CREBBP', 'KAT2B'],
#  'SMAD1-P300 complex': ['EP300', 'SMAD1'],
#  'MYC-DNMT3A-ZBTB17 complex': ['MYC', 'ZBTB17', 'DNMT3A'],
#  'DNMT3B-DNMT3L complex': ['DNMT3B', 'DNMT3L'],
#  'DNMT3L-DNMT3A complex': ['DNMT3L', 'DNMT3A'],
#  'MYC-MAX-KAT2A-TRRAP complex': ['MYC', 'MAX', 'KAT2A', 'TRRAP'],
#  'MYC-MAX complex': ['MYC', 'MAX'],
#  'ESR1-CDK7-CCNH-MNAT1-MTA1-HDAC2 complex': ['ESR1',
#   'CDK7',
#   'CCNH',
#   'MNAT1',
#   'MTA1',
#   'HDAC2'],
#  'Er-alpha-p53-hdm2 complex': ['ESR1', 'TP53', 'MDM2'],
#  'FOXO3-TP53 complex, oxidative stress stimulated': ['FOXO3', 'TP53'],
#  'p53-SP1 complex': ['TP53', 'SP1'],
#  'p53 homotetramer complex': ['TP53'],
#  'RNA polymerase II (RNAPII)': ['POLR2D',
#   'GTF2F2',
#   'POLR2C',
#   'POLR2E',
#   'POLR2A',
#   'POLR2B',
#   'GTF2F1',
#   'POLR2I',
#   'POLR2H',
#   'POLR2J',
#   'POLR2K',
#   'POLR2F',
#   'POLR2G',
#   'POLR2L',
#   'GTF2B',
#   'RPAP1',
#   'CTDP1'],
#  'BRCA1-core RNA polymerase II complex': ['POLR2D',
#   'POLR2C',
#   'POLR2E',
#   'POLR2A',
#   'POLR2B',
#   'POLR2I',
#   'BRCA1',
#   'POLR2H',
#   'POLR2J',
#   'POLR2K',
#   'POLR2F',
#   'POLR2G',
#   'POLR2L'],
#  'MMP14-CLDN1 complex': ['CLDN1', 'MMP14'],
#  'SMAD3-SMAD4-cJun-cFos complex': ['FOS', 'JUN', 'SMAD3', 'SMAD4'],
#  'NFAT-JUN-FOS DNA-protein complex': ['FOS', 'JUN', 'NFATC2'],
#  'ERG-JUN-FOS DNA-protein complex': ['FOS', 'JUN', 'ERG'],
#  'ETS2-FOS-JUN complex': ['FOS', 'JUN', 'ETS2'],
#  'ESR1-JUN-GRIP1 complex': ['ESR1', 'JUN', 'GRIP1'],
#  'ESR1-JUN complex': ['ESR1', 'JUN'],
#  ...}

# %% [markdown]
# ### Define basic analysis functions

# %%
def find_ratios(protein_list, patient_id, data):
    patient_normal_id = patient_id + '_NM'
    cancer_total = 0
    normal_total = 0
    cancer_ratios = []
    normal_ratios = []
    for protein in protein_list:
        cancer_total += data.at[protein, patient_id]
        normal_total += data.at[protein, patient_normal_id]
    for protein in protein_list:
        cancer_ratios.append((data.at[protein, patient_id]) / cancer_total)
        normal_ratios.append((data.at[protein, patient_normal_id]) / normal_total)
    return cancer_ratios, normal_ratios
