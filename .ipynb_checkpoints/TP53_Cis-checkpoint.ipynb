# %% [markdown]
# # Analyzing the cis effects of TP53 mutation on p53

# %% [markdown]
# Our first step was to determine the ways in which TP53 mutation affects the protein that the TP53 gene codes for: p53. These are called cis effects.

# %% [markdown]
# ### Standard imports, including CPTAC package

# %%
import pandas as pd
import numpy as np
import re
import scipy.stats
import statsmodels.stats.multitest
import matplotlib.pyplot as plt
import seaborn as sns
import CPTAC.Ovarian as CPTAC
# Out:
# Welcome to the CPTAC data service package. Available datasets may be
# viewed using CPTAC.list(). In order to access a specific data set,
# import a CPTAC subfolder using either 'import CPTAC.Dataset' or 'from
# CPTAC import Dataset'.
# ******
# Version: 0.2.5
# ******
# Loading Ovarian CPTAC data:
# Loading somatic_19 data...
# Loading clinical data...
# Loading cnv data...
# Loading proteomics data...
# Loading transcriptomics data...
# Loading somatic_38 data...
# Loading phosphoproteomics data...
#
#  ******PLEASE READ******
# WARNING: This data is under a publication embargo until June 1, 2019.
# CPTAC is a community resource project and data are made available
# rapidly after generation for community research use. The embargo
# allows exploring and utilizing the data, but the data may not be in a
# publication until June 1, 2019. Please see
# https://proteomics.cancer.gov/data-portal/about/data-use-agreement or
# enter embargo() to open the webpage for more details.

# %% [markdown]
# ## Set up initial dataframes and variables

# %%
gene='TP53'
somatic = CPTAC.get_somatic_mutations()
proteomics = CPTAC.get_proteomics()
phos = CPTAC.get_phosphoproteomics()
transcriptomics = CPTAC.get_transcriptomics()
# A list of mutations present in the hotspot according to our Hotspot3D output
hotspot_mutations = ['p.R248L','p.R248Q','p.R248W','p.C275Y','p.K132N','p.R273C','p.R273H','p.R282W','p.V274A',
                     'p.M237I','p.R156P','p.R175H','p.G245D','p.G245S','p.C238F','p.C238Y']

# %% [markdown]
# ## Find patients with hotspot mutations

# %%
mutated_hotspot = somatic.loc[(somatic['Location'].isin(hotspot_mutations))]
mutated_hotspot = mutated_hotspot.loc[(mutated_hotspot['Gene'] == gene)]

# Get a list of patient identifiers for those who have mutations in the hotspot
hotspot_patients = mutated_hotspot['patient_key']
hotspot_patients
# Out:
# Patient_Id
# 01OV018      S7
# 02OV032     S27
# 04OV004     S37
# 04OV012     S41
# 04OV018     S44
# 04OV037     S53
# 04OV045     S58
# 04OV048     S59
# 04OV050     S61
# 04OV053     S63
# 14OV011     S73
# 15OV001     S74
# 17OV010     S82
# 17OV010     S82
# 17OV017     S89
# 17OV025     S93
# 17OV027     S95
# 17OV030     S98
# 17OV039    S106
# 17OV040    S107
# 18OV001    S108
# 20OV005    S109
# 26OV009    S113
# 26OV011    S115
# 26OV013    S116
# Name: patient_key, dtype: object

# %% [markdown]
# ### Determine the number of patients with TP53 mutations inside and outside of the hotspot

# %%
print("Mutations inside hotspot: " + str(len(hotspot_patients)))
p53_mutated = somatic.loc[somatic['Gene'] == gene]

# Some people have more than one mutation so we need to grab the unique values
num_mutated = len(set(p53_mutated['patient_key']))
print("Total number of patients with mutations: " + str(num_mutated))
print("Total number of patients: " + str(len(set(somatic['patient_key']))))
# Out:
# Mutations inside hotspot: 25
# Total number of patients with mutations: 77
# Total number of patients: 83

# %% [markdown]
# # TP53 cis effects

# %% [markdown]
# ## Proteomic analysis

# %% [markdown]
# First we analyze the protein expression (proteomics) of p53 when TP53 is mutated

# %%
protein = 'TP53'
# 1.  Merge the mutation status of P53 and the proteomics data of P53
p53_mutations_protein = CPTAC.compare_mutations(proteomics, protein, gene).set_index('patient_key')

# 2. Set up a new column for mutations that are within the hotspot
p53_mutations_protein['Within_Hotspot'] = 'Outside Hotspot'
p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = 'Within Hotspot'
p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype_Tumor', 'Within_Hotspot'] = 'Wildtype'

# 3. Select for tumor samples only
p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Sample_Status'] == 'Tumor'].dropna(axis=0)

# 4.  Make two new DFs, one for people with a hotspot mutation, one for all the wildtype cancer patients.
mutated_htspt = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == 'Within Hotspot']
p53_non_htspt = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == 'Outside Hotspot']
wt = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] == 'Wildtype']

# 5. ttest for proteomics of TP53 between wildtype cancer and hotspot mutation
ttest = scipy.stats.ttest_ind(mutated_htspt[protein], wt[protein])
print(protein + " proteomics hotspot mutation vs wildtype: " + str(ttest[1]))

# 6. Perform a ttest for non-hotspot mutations vs wildtype
ttest = scipy.stats.ttest_ind(p53_non_htspt[protein], wt[protein])
print("Non-hotspot TP53 mutation vs wildtype: " + str(ttest[1]))

# 7. Repeat for all mutations vs wildtype cancer
all_mutated = p53_mutations_protein.loc[p53_mutations_protein['Within_Hotspot'] != 'Wildtype']
ttest = scipy.stats.ttest_ind(all_mutated[protein], wt[protein])
print(protein + " proteomics all mutation vs wildtype: " + str(ttest[1]))

# 8. Repeat for hotspot vs non-hotspot mutations
ttest = scipy.stats.ttest_ind(mutated_htspt[protein], p53_non_htspt[protein])
print(protein + " proteomics hotspot mutation vs non-hotspot mutation: " + str(ttest[1]))

# 9. Plot the data
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize = a4_dims)
boxplt = sns.boxplot(data = p53_mutations_protein, x = 'Within_Hotspot', order = ['Wildtype', 'Within Hotspot', 'Outside Hotspot'], y = protein, ax = ax)
boxplt = sns.stripplot(data = p53_mutations_protein, x = 'Within_Hotspot', y = protein, order = ['Wildtype', 'Within Hotspot', 'Outside Hotspot'], jitter = True, color = '.3')
boxplt.set_xlabel('Mutation Location', fontsize='20')
boxplt.set_ylabel('Protein Expression', fontsize='20')
boxplt.set_title("Effect of " + gene + " mutation on " + protein + " proteomics", fontsize='22')
plt.show()
# Out:
# TP53 proteomics hotspot mutation vs wildtype: 0.0007780033888554917
# Non-hotspot TP53 mutation vs wildtype: 0.492819007106129
# TP53 proteomics all mutation vs wildtype: 0.2066984975883061
# TP53 proteomics hotspot mutation vs non-hotspot mutation: 0.003106796005300394

# %% [markdown]
# ## Phosphoproteomic analysis

# %% [markdown]
# Now we look at the phosphorylation of p53 when TP53 is mutated

# %%
p53_mutations_protein
# Out:
#              TP53-S315s  TP53-S315s  TP53-S315s  TP53-S315s  TP53-S315s  \
# patient_key
# S2                  NaN         NaN         NaN         NaN         NaN
# S6                  NaN         NaN         NaN         NaN         NaN
# S7                  NaN         NaN         NaN         NaN         NaN
# S9               -3.017         NaN      -3.017      -3.017         NaN
# S11              -1.976         NaN      -1.976      -1.976         NaN
# S12                 NaN         NaN         NaN         NaN         NaN
# S13                 NaN      -1.510         NaN         NaN      -1.510
# S14                 NaN         NaN         NaN         NaN         NaN
# S15              -3.127         NaN      -3.127      -3.127         NaN
# S18              -3.987         NaN      -3.987      -3.987         NaN
# S20                 NaN         NaN         NaN         NaN         NaN
# S21              -2.167         NaN      -2.167      -2.167         NaN
# S22              -2.845         NaN      -2.845      -2.845         NaN
# S23                 NaN         NaN         NaN         NaN         NaN
# S24              -4.192         NaN      -4.192      -4.192         NaN
# S25                 NaN       0.107         NaN         NaN       0.107
# S26              -4.714         NaN      -4.714      -4.714         NaN
# S27              -4.577         NaN      -4.577      -4.577         NaN
# S29              -2.600         NaN      -2.600      -2.600         NaN
# S31                 NaN         NaN         NaN         NaN         NaN
# S33              -4.706         NaN      -4.706      -4.706         NaN
# S35                 NaN      -1.490         NaN         NaN      -1.490
# S36              -4.983         NaN      -4.983      -4.983         NaN
# S37              -3.321         NaN      -3.321      -3.321         NaN
# S38                 NaN         NaN         NaN         NaN         NaN
# S39              -2.761         NaN      -2.761      -2.761         NaN
# S40              -2.145         NaN      -2.145      -2.145         NaN
# S41              -1.056         NaN      -1.056      -1.056         NaN
# S42              -3.887         NaN      -3.887      -3.887         NaN
# S43                 NaN         NaN         NaN         NaN         NaN
# ...                 ...         ...         ...         ...         ...
# S68              -4.575         NaN      -4.575      -4.575         NaN
# S69              -1.568         NaN      -1.568      -1.568         NaN
# S71              -3.023         NaN      -3.023      -3.023         NaN
# S73              -2.012         NaN      -2.012      -2.012         NaN
# S74              -2.759         NaN      -2.759      -2.759         NaN
# S75              -4.752         NaN      -4.752      -4.752         NaN
# S76              -3.981         NaN      -3.981      -3.981         NaN
# S82                 NaN         NaN         NaN         NaN         NaN
# S83              -3.643         NaN      -3.643      -3.643         NaN
# S85              -3.384         NaN      -3.384      -3.384         NaN
# S86                 NaN         NaN         NaN         NaN         NaN
# S87              -3.547         NaN      -3.547      -3.547         NaN
# S89              -2.196         NaN      -2.196      -2.196         NaN
# S90                 NaN         NaN         NaN         NaN         NaN
# S93                 NaN         NaN         NaN         NaN         NaN
# S95              -0.575         NaN      -0.575      -0.575         NaN
# S96               0.490         NaN       0.490       0.490         NaN
# S97              -3.904         NaN      -3.904      -3.904         NaN
# S98              -2.231         NaN      -2.231      -2.231         NaN
# S100                NaN         NaN         NaN         NaN         NaN
# S103                NaN         NaN         NaN         NaN         NaN
# S106             -1.837         NaN      -1.837      -1.837         NaN
# S107                NaN         NaN         NaN         NaN         NaN
# S108                NaN         NaN         NaN         NaN         NaN
# S109             -0.574         NaN      -0.574      -0.574         NaN
# S111                NaN      -2.077         NaN         NaN      -2.077
# S112             -1.466         NaN      -1.466      -1.466         NaN
# S113             -1.265         NaN      -1.265      -1.265         NaN
# S115             -1.842         NaN      -1.842      -1.842         NaN
# S116                NaN         NaN         NaN         NaN         NaN
#
#              TP53-S315s  TP53-S315s  TP53-S315s  TP53-S315s  TP53-S315s  \
# patient_key
# S2                  NaN         NaN         NaN         NaN         NaN
# S6                  NaN         NaN         NaN         NaN         NaN
# S7                  NaN         NaN         NaN         NaN         NaN
# S9               -3.017         NaN      -3.017         NaN         NaN
# S11              -1.976         NaN      -1.976         NaN         NaN
# S12                 NaN         NaN         NaN         NaN         NaN
# S13                 NaN      -1.510         NaN      -1.510      -1.510
# S14                 NaN         NaN         NaN         NaN         NaN
# S15              -3.127         NaN      -3.127         NaN         NaN
# S18              -3.987         NaN      -3.987         NaN         NaN
# S20                 NaN         NaN         NaN         NaN         NaN
# S21              -2.167         NaN      -2.167         NaN         NaN
# S22              -2.845         NaN      -2.845         NaN         NaN
# S23                 NaN         NaN         NaN         NaN         NaN
# S24              -4.192         NaN      -4.192         NaN         NaN
# S25                 NaN       0.107         NaN       0.107       0.107
# S26              -4.714         NaN      -4.714         NaN         NaN
# S27              -4.577         NaN      -4.577         NaN         NaN
# S29              -2.600         NaN      -2.600         NaN         NaN
# S31                 NaN         NaN         NaN         NaN         NaN
# S33              -4.706         NaN      -4.706         NaN         NaN
# S35                 NaN      -1.490         NaN      -1.490      -1.490
# S36              -4.983         NaN      -4.983         NaN         NaN
# S37              -3.321         NaN      -3.321         NaN         NaN
# S38                 NaN         NaN         NaN         NaN         NaN
# S39              -2.761         NaN      -2.761         NaN         NaN
# S40              -2.145         NaN      -2.145         NaN         NaN
# S41              -1.056         NaN      -1.056         NaN         NaN
# S42              -3.887         NaN      -3.887         NaN         NaN
# S43                 NaN         NaN         NaN         NaN         NaN
# ...                 ...         ...         ...         ...         ...
# S68              -4.575         NaN      -4.575         NaN         NaN
# S69              -1.568         NaN      -1.568         NaN         NaN
# S71              -3.023         NaN      -3.023         NaN         NaN
# S73              -2.012         NaN      -2.012         NaN         NaN
# S74              -2.759         NaN      -2.759         NaN         NaN
# S75              -4.752         NaN      -4.752         NaN         NaN
# S76              -3.981         NaN      -3.981         NaN         NaN
# S82                 NaN         NaN         NaN         NaN         NaN
# S83              -3.643         NaN      -3.643         NaN         NaN
# S85              -3.384         NaN      -3.384         NaN         NaN
# S86                 NaN         NaN         NaN         NaN         NaN
# S87              -3.547         NaN      -3.547         NaN         NaN
# S89              -2.196         NaN      -2.196         NaN         NaN
# S90                 NaN         NaN         NaN         NaN         NaN
# S93                 NaN         NaN         NaN         NaN         NaN
# S95              -0.575         NaN      -0.575         NaN         NaN
# S96               0.490         NaN       0.490         NaN         NaN
# S97              -3.904         NaN      -3.904         NaN         NaN
# S98              -2.231         NaN      -2.231         NaN         NaN
# S100                NaN         NaN         NaN         NaN         NaN
# S103                NaN         NaN         NaN         NaN         NaN
# S106             -1.837         NaN      -1.837         NaN         NaN
# S107                NaN         NaN         NaN         NaN         NaN
# S108                NaN         NaN         NaN         NaN         NaN
# S109             -0.574         NaN      -0.574         NaN         NaN
# S111                NaN      -2.077         NaN      -2.077      -2.077
# S112             -1.466         NaN      -1.466         NaN         NaN
# S113             -1.265         NaN      -1.265         NaN         NaN
# S115             -1.842         NaN      -1.842         NaN         NaN
# S116                NaN         NaN         NaN         NaN         NaN
#
#                   ...         TP53-S315s  TP53-S315s  TP53-S315s  TP53-S315s  \
# patient_key       ...
# S2                ...                NaN         NaN         NaN         NaN
# S6                ...                NaN         NaN         NaN         NaN
# S7                ...                NaN         NaN         NaN         NaN
# S9                ...                NaN      -3.017         NaN      -3.017
# S11               ...                NaN      -1.976         NaN      -1.976
# S12               ...                NaN         NaN         NaN         NaN
# S13               ...             -1.510         NaN      -1.510         NaN
# S14               ...                NaN         NaN         NaN         NaN
# S15               ...                NaN      -3.127         NaN      -3.127
# S18               ...                NaN      -3.987         NaN      -3.987
# S20               ...                NaN         NaN         NaN         NaN
# S21               ...                NaN      -2.167         NaN      -2.167
# S22               ...                NaN      -2.845         NaN      -2.845
# S23               ...                NaN         NaN         NaN         NaN
# S24               ...                NaN      -4.192         NaN      -4.192
# S25               ...              0.107         NaN       0.107         NaN
# S26               ...                NaN      -4.714         NaN      -4.714
# S27               ...                NaN      -4.577         NaN      -4.577
# S29               ...                NaN      -2.600         NaN      -2.600
# S31               ...                NaN         NaN         NaN         NaN
# S33               ...                NaN      -4.706         NaN      -4.706
# S35               ...             -1.490         NaN      -1.490         NaN
# S36               ...                NaN      -4.983         NaN      -4.983
# S37               ...                NaN      -3.321         NaN      -3.321
# S38               ...                NaN         NaN         NaN         NaN
# S39               ...                NaN      -2.761         NaN      -2.761
# S40               ...                NaN      -2.145         NaN      -2.145
# S41               ...                NaN      -1.056         NaN      -1.056
# S42               ...                NaN      -3.887         NaN      -3.887
# S43               ...                NaN         NaN         NaN         NaN
# ...               ...                ...         ...         ...         ...
# S68               ...                NaN      -4.575         NaN      -4.575
# S69               ...                NaN      -1.568         NaN      -1.568
# S71               ...                NaN      -3.023         NaN      -3.023
# S73               ...                NaN      -2.012         NaN      -2.012
# S74               ...                NaN      -2.759         NaN      -2.759
# S75               ...                NaN      -4.752         NaN      -4.752
# S76               ...                NaN      -3.981         NaN      -3.981
# S82               ...                NaN         NaN         NaN         NaN
# S83               ...                NaN      -3.643         NaN      -3.643
# S85               ...                NaN      -3.384         NaN      -3.384
# S86               ...                NaN         NaN         NaN         NaN
# S87               ...                NaN      -3.547         NaN      -3.547
# S89               ...                NaN      -2.196         NaN      -2.196
# S90               ...                NaN         NaN         NaN         NaN
# S93               ...                NaN         NaN         NaN         NaN
# S95               ...                NaN      -0.575         NaN      -0.575
# S96               ...                NaN       0.490         NaN       0.490
# S97               ...                NaN      -3.904         NaN      -3.904
# S98               ...                NaN      -2.231         NaN      -2.231
# S100              ...                NaN         NaN         NaN         NaN
# S103              ...                NaN         NaN         NaN         NaN
# S106              ...                NaN      -1.837         NaN      -1.837
# S107              ...                NaN         NaN         NaN         NaN
# S108              ...                NaN         NaN         NaN         NaN
# S109              ...                NaN      -0.574         NaN      -0.574
# S111              ...             -2.077         NaN      -2.077         NaN
# S112              ...                NaN      -1.466         NaN      -1.466
# S113              ...                NaN      -1.265         NaN      -1.265
# S115              ...                NaN      -1.842         NaN      -1.842
# S116              ...                NaN         NaN         NaN         NaN
#
#              TP53-S315s  TP53-S315s  TP53-S315s  TP53-S315s  \
# patient_key
# S2                  NaN         NaN         NaN         NaN
# S6                  NaN         NaN         NaN         NaN
# S7                  NaN         NaN         NaN         NaN
# S9               -3.017      -3.017         NaN         NaN
# S11              -1.976      -1.976         NaN         NaN
# S12                 NaN         NaN         NaN         NaN
# S13                 NaN         NaN      -1.510      -1.510
# S14                 NaN         NaN         NaN         NaN
# S15              -3.127      -3.127         NaN         NaN
# S18              -3.987      -3.987         NaN         NaN
# S20                 NaN         NaN         NaN         NaN
# S21              -2.167      -2.167         NaN         NaN
# S22              -2.845      -2.845         NaN         NaN
# S23                 NaN         NaN         NaN         NaN
# S24              -4.192      -4.192         NaN         NaN
# S25                 NaN         NaN       0.107       0.107
# S26              -4.714      -4.714         NaN         NaN
# S27              -4.577      -4.577         NaN         NaN
# S29              -2.600      -2.600         NaN         NaN
# S31                 NaN         NaN         NaN         NaN
# S33              -4.706      -4.706         NaN         NaN
# S35                 NaN         NaN      -1.490      -1.490
# S36              -4.983      -4.983         NaN         NaN
# S37              -3.321      -3.321         NaN         NaN
# S38                 NaN         NaN         NaN         NaN
# S39              -2.761      -2.761         NaN         NaN
# S40              -2.145      -2.145         NaN         NaN
# S41              -1.056      -1.056         NaN         NaN
# S42              -3.887      -3.887         NaN         NaN
# S43                 NaN         NaN         NaN         NaN
# ...                 ...         ...         ...         ...
# S68              -4.575      -4.575         NaN         NaN
# S69              -1.568      -1.568         NaN         NaN
# S71              -3.023      -3.023         NaN         NaN
# S73              -2.012      -2.012         NaN         NaN
# S74              -2.759      -2.759         NaN         NaN
# S75              -4.752      -4.752         NaN         NaN
# S76              -3.981      -3.981         NaN         NaN
# S82                 NaN         NaN         NaN         NaN
# S83              -3.643      -3.643         NaN         NaN
# S85              -3.384      -3.384         NaN         NaN
# S86                 NaN         NaN         NaN         NaN
# S87              -3.547      -3.547         NaN         NaN
# S89              -2.196      -2.196         NaN         NaN
# S90                 NaN         NaN         NaN         NaN
# S93                 NaN         NaN         NaN         NaN
# S95              -0.575      -0.575         NaN         NaN
# S96               0.490       0.490         NaN         NaN
# S97              -3.904      -3.904         NaN         NaN
# S98              -2.231      -2.231         NaN         NaN
# S100                NaN         NaN         NaN         NaN
# S103                NaN         NaN         NaN         NaN
# S106             -1.837      -1.837         NaN         NaN
# S107                NaN         NaN         NaN         NaN
# S108                NaN         NaN         NaN         NaN
# S109             -0.574      -0.574         NaN         NaN
# S111                NaN         NaN      -2.077      -2.077
# S112             -1.466      -1.466         NaN         NaN
# S113             -1.265      -1.265         NaN         NaN
# S115             -1.842      -1.842         NaN         NaN
# S116                NaN         NaN         NaN         NaN
#
#                       Mutation   Within_Hotspot
# patient_key
# S2             Frame_Shift_Del  Outside Hotspot
# S6             Frame_Shift_Del  Outside Hotspot
# S7           Missense_Mutation   Within Hotspot
# S9           Missense_Mutation  Outside Hotspot
# S11            Frame_Shift_Ins  Outside Hotspot
# S12             Wildtype_Tumor         Wildtype
# S13                Splice_Site  Outside Hotspot
# S14          Missense_Mutation  Outside Hotspot
# S15            Frame_Shift_Ins  Outside Hotspot
# S18             Wildtype_Tumor         Wildtype
# S20          Nonsense_Mutation  Outside Hotspot
# S21                Splice_Site  Outside Hotspot
# S22          Missense_Mutation  Outside Hotspot
# S23             Wildtype_Tumor         Wildtype
# S24            Frame_Shift_Del  Outside Hotspot
# S25          Missense_Mutation  Outside Hotspot
# S26            Frame_Shift_Del  Outside Hotspot
# S27          Missense_Mutation   Within Hotspot
# S29          Nonsense_Mutation  Outside Hotspot
# S31                Splice_Site  Outside Hotspot
# S33                Splice_Site  Outside Hotspot
# S35               In_Frame_Del  Outside Hotspot
# S36            Frame_Shift_Ins  Outside Hotspot
# S37          Missense_Mutation   Within Hotspot
# S38            Frame_Shift_Del  Outside Hotspot
# S39               In_Frame_Del  Outside Hotspot
# S40          Nonsense_Mutation  Outside Hotspot
# S41          Missense_Mutation   Within Hotspot
# S42          Missense_Mutation  Outside Hotspot
# S43            Frame_Shift_Del  Outside Hotspot
# ...                        ...              ...
# S68            Frame_Shift_Del  Outside Hotspot
# S69          Missense_Mutation  Outside Hotspot
# S71             Wildtype_Tumor         Wildtype
# S73          Missense_Mutation   Within Hotspot
# S74          Missense_Mutation   Within Hotspot
# S75            Frame_Shift_Del  Outside Hotspot
# S76          Nonsense_Mutation  Outside Hotspot
# S82          Missense_Mutation   Within Hotspot
# S83                Splice_Site  Outside Hotspot
# S85             Wildtype_Tumor         Wildtype
# S86          Missense_Mutation  Outside Hotspot
# S87            Frame_Shift_Del  Outside Hotspot
# S89          Missense_Mutation   Within Hotspot
# S90            Frame_Shift_Del  Outside Hotspot
# S93          Missense_Mutation   Within Hotspot
# S95          Missense_Mutation   Within Hotspot
# S96          Missense_Mutation  Outside Hotspot
# S97            Frame_Shift_Del  Outside Hotspot
# S98          Missense_Mutation   Within Hotspot
# S100         Missense_Mutation  Outside Hotspot
# S103           Frame_Shift_Del  Outside Hotspot
# S106         Missense_Mutation   Within Hotspot
# S107         Missense_Mutation   Within Hotspot
# S108         Missense_Mutation   Within Hotspot
# S109         Missense_Mutation   Within Hotspot
# S111         Missense_Mutation  Outside Hotspot
# S112           Frame_Shift_Del  Outside Hotspot
# S113         Missense_Mutation   Within Hotspot
# S115         Missense_Mutation   Within Hotspot
# S116         Missense_Mutation   Within Hotspot
#
# [83 rows x 578 columns]

# %%
protein = 'TP53-'
pattern = re.compile(protein)

# 1. Create a dataframe combining phosphosite data with TP53 mutation status; select for tumor samples
p53_mutations_protein = CPTAC.compare_mutations(phos, protein, gene).set_index('patient_key')
p53_mutations_protein = p53_mutations_protein.loc[p53_mutations_protein['Sample_Status'] == 'Tumor'].drop('Sample_Status', axis=1)

# 2. Make a new column for mutation location relative to hotspot
p53_mutations_protein['Within_Hotspot'] = 'Outside Hotspot'
p53_mutations_protein.loc[hotspot_patients, 'Within_Hotspot'] = 'Within Hotspot'
p53_mutations_protein.loc[p53_mutations_protein['Mutation'] == 'Wildtype_Tumor', 'Within_Hotspot'] = 'Wildtype'
p53_mutations_protein.drop('Mutation', axis=1)

# 3. Begin constructing a dataframe for plotting, starting only with the mutation location
plotdf = p53_mutations_protein[['Within_Hotspot']]

# 4. Loop through each phosphosite to check for significance:
for site in p53_mutations_protein.columns:
    if (site != 'Within_Hotspot' and site != 'Mutation'):
        sitedf = p53_mutations_protein[[site, 'Within_Hotspot']].dropna(axis=0)
        tp53_phos_htspt = sitedf.loc[sitedf['Within_Hotspot'] == 'Within Hotspot']
        tp53_phos_non_htspt = sitedf.loc[sitedf['Within_Hotspot'] == 'Outside Hotspot']
        tp53_phos_wt = sitedf.loc[sitedf['Within_Hotspot'] == 'Wildtype']
        tp53_phos_all_mut = sitedf.loc[sitedf['Within_Hotspot'] != 'Wildtype']
        
        #Perform a ttest for hotspot vs wildtype
        ttest = scipy.stats.ttest_ind(tp53_phos_htspt[site], tp53_phos_wt[site])
        print("TP53 hotspot mutation and " + site + ": " + str(ttest[1]))
        plotdf = plotdf.join(p53_mutations_protein[site])
        
        #Perform a ttest for all mutations vs wildtype
        ttest = scipy.stats.ttest_ind(tp53_phos_all_mut[site], tp53_phos_wt[site])
        print("All TP53 mutation and " + site + ": " + str(ttest[1]))
        
        #Perform a ttest for non-hotspot mutations vs wildtype
        ttest = scipy.stats.ttest_ind(tp53_phos_non_htspt[site], tp53_phos_wt[site])
        print("Non-hotspot TP53 mutation and " + site + ": " + str(ttest[1]))
        

# 5. Plot the sites
plotdf = pd.melt(plotdf, id_vars = ['Within_Hotspot'], var_name = 'Site', value_name = 'Phos')
plotdf = plotdf.dropna(axis = 0)
            
a4_dims = (23.4, 16.54)
fig, ax = plt.subplots(figsize=a4_dims)

#Create the plot
boxplt = sns.boxplot(x='Site', y='Phos', hue='Within_Hotspot', hue_order = ['Wildtype', 'Within Hotspot', 'Outside Hotspot'], data=plotdf)
boxplt = sns.stripplot(data=plotdf, x='Site', y='Phos', hue='Within_Hotspot', hue_order = ['Wildtype', 'Within Hotspot', 'Outside Hotspot'], dodge=True, jitter=True, color='.3')

#Add styling
boxplt.set_xlabel('')
boxplt.set_ylabel('Phosphoproteome Level', fontsize='40')
boxplt.tick_params(labelsize='25')
handles, labels = ax.get_legend_handles_labels()
plt.legend(handles[0:3], ['Wildtype', 'Within Hotspot', 'Outside Hotspot'], title='TP53 Mutation Location', fontsize='20', frameon=False)
boxplt.get_legend().get_title().set_fontsize('20')
boxplt.get_legend().set_bbox_to_anchor((0.95, 0.95, 0, 0))
# Out:
# TP53 hotspot mutation and TP53-S315s: nan
# All TP53 mutation and TP53-S315s: nan
# Non-hotspot TP53 mutation and TP53-S315s: nan
# TP53 hotspot mutation and TP53-S315s: nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-404b28a170a9> in <module>()
#      27         ttest = scipy.stats.ttest_ind(tp53_phos_htspt[site], tp53_phos_wt[site])
#      28         print("TP53 hotspot mutation and " + site + ": " + str(ttest[1]))
# ---> 29         plotdf = plotdf.join(p53_mutations_protein[site])
#      30
#      31         #Perform a ttest for all mutations vs wildtype
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6334         # For SparseDataFrame's benefit
#    6335         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6336                                  rsuffix=rsuffix, sort=sort)
#    6337
#    6338     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6349             return merge(self, other, left_on=on, how=how,
#    6350                          left_index=on is None, right_index=True,
# -> 6351                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6352         else:
#    6353             if on is not None:
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     572
#     573         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 574                                                      rdata.items, rsuf)
#     575
#     576         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/pandas/core/internals.py in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    5242         if not lsuffix and not rsuffix:
#    5243             raise ValueError('columns overlap but no suffix specified: '
# -> 5244                              '{rename}'.format(rename=to_rename))
#    5245
#    5246         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index(['TP53-S315s', 'TP53-S315s', 'TP53-S315s', 'TP53-S315s', 'TP53-S315s',
#        'TP53-S315s', 'TP53-S315s', 'TP53-S315s', 'TP53-S315s', 'TP53-S315s',
#        ...
#        'TP53-S315s', 'TP53-S315s', 'TP53-S315s', 'TP53-S315s', 'TP53-S315s',
#        'TP53-S315s', 'TP53-S315s', 'TP53-S315s', 'TP53-S315s', 'TP53-S315s'],
#       dtype='object', length=576)
